# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from spellchecker import SpellChecker
from gensim.models import FastText
import re
import nltk
import contractions
from datetime import datetime
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split, cross_validate, StratifiedKFold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import LabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.layers import Bidirectional
import numpy as np
import spacy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle
import seaborn as sns

# Download NLTK resources
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/joaocosta/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/joaocosta/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Reading the file and converting it to a DataFrame
def read_file_to_dataframe(filename):
    data = []
    
    with open("./data/" + filename, 'r', encoding='utf-8') as file:
        for linha in file:
            linha = linha.strip()  # Remove leading/trailing spaces and newlines
            filme = linha.split('\t')  # Split by tab
            data.append(filme)  # Append the row to the data list
    
    # Convert the list of rows to a pandas DataFrame
    df = pd.DataFrame(data)
    
    return df

# %% [markdown]
# # Variaveis onde está os ficheiros de treino e o modelo

# %%
#file onde já está o modelo treinado"
model=None
newPKL = "joao3"


#limpesa de ficheiro de treino
data="train"
#ficheiro onde vai ser feita ao autoavaliacao
avaliation = "test_no_labels"

# %%
print("\033[34mData to DataFrame\n\033[0m")
# Example usage
df = read_file_to_dataframe(data+".txt")
print(df)
# Out:
# Data to DataFrame
#
#                               0          1        2                        3  \
# 0                  Ela Cheppanu     Telugu  romance                   Ramana
# 1     A Nightmare on Elm Street   American   horror             Samuel Bayer
# 2               American Gothic   American   horror               John Hough
# 3                          Gang  Bollywood    crime              Mazhar Khan
# 4            Intimate Relations    British    drama            Charles Frank
# ...                         ...        ...      ...                      ...
# 8036              Sa 'Yo Lamang   Filipino    drama          Laurice Guillen
# 8037          The Lemon Sisters   American    drama             Joyce Chopra
# 8038      Dil Ne Phir Yaad Kiya  Bollywood  romance                  Unknown
# 8039  Rehnaa Hai Terre Dil Mein  Bollywood  romance            Gautham Menon
# 8040             Things to Come    British   sci-fi  William Cameron Menzies
#
#                                                       4
# 0     Sekhar (Tarun) is a graduate from IIM and work...
# 1     Kris Fowles (Katie Cassidy) goes to the Spring...
# 2     Cynthia is traumatized by the death of her bab...
# 3     Four friends, Gangu (Jackie Shroff), Abdul (Na...
# 4     Crisis in a middle-class family when the son f...
# ...                                                 ...
# 8036  Dianne seems to have a happy family. She and h...
# 8037  Three lifelong friends work the bars in 1980's...
# 8038  City-based Ashok, who works as a Salesman in a...
# 8039  The story starts with narration by Maddy (R. M...
# 8040  In the British city of Everytown, businessman ...
#
# [8041 rows x 5 columns]

# %%
# histogram of word count
print(len(df))

df['word_count'] = df[4].apply(lambda x: len(x.split()))
avg_word_count = df['word_count'].mean()
print(f'Average word count: {avg_word_count:.2f}')
# Plotting the histogram of word counts
plt.figure(figsize=(10, 2))
plt.hist(df['word_count'], bins=80, color='skyblue', edgecolor='black')
plt.title('Histogram of Word Counts in summarization of movies')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# 8041
# Average word count: 370.33

# %%
# Flatten all words from the 4th column into a single list
all_words = [word for row in df[4] for word in row.split()]

word_counter = Counter(all_words)

top_10_words = word_counter.most_common(10)

for word, count in top_10_words:
    print(f"{word}: {count}")

words, counts = zip(*top_10_words)

plt.figure(figsize=(10, 4))
plt.bar(words, counts, color='lightcoral')
plt.title('Top 10 Most Common Words in 4th Column')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate word labels for better readability
plt.tight_layout()
plt.show()
# Out:
# the: 161014
# to: 111607
# and: 106034
# a: 80092
# of: 53504
# is: 49072
# his: 43843
# in: 43811
# he: 30869
# that: 30744

# %%
# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counter)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off the axis
plt.title('Word Cloud of Words in 4th Column')
plt.show()

# %%
# Check for typos using the pyspellchecker
spell = SpellChecker()
misspelled_words = spell.unknown(all_words)  # Identify misspelled words

# Display the number of potential typos
print(f"Number of potential typos: {len(misspelled_words)}")

# Optionally, print the misspelled words
print("\nPotential typos detected:")
for word in misspelled_words:
    print(word)
# Out:
# Number of potential typos: 110045
#
# Potential typos detected:
# shahnawaz's
# larrabee's
# trey.
# wolf's,
# bangles,
# ranjeeta's
# charge-pritam
# of:
# (hulbert)
# libbie
# (means,
# 300-foot
# blackjack,
# (sumita
# bhinder
# unbalanced.
# sneham
# put-down.
# ranch.
# convoy)
# ssgt
# batman/bruce
# learned).
# work,
# (florence
# hartnett)
# spikes,
# brain-eating
# why.
# talbott
# zoya.
# mail.
# damien;
# julie-8
# fence.
# 1966,
# keating),
# gamblers.
# kathavarayan
# racine
# tei
# (tress
# pillows.
# murakami,
# lombardi)
# entertainer)
# rasc
# clavis,
# (karl
# inorder
# moses),
# baachi
# self-involved.
# later,
# balk)
# (eunice
# hannuma
# privately.
# coryton's
# guard;
# on-again
# headache.
# emma,
# dead...
# snake’s
# post-modern
# cactus-thorn-riddled
# merteuil
# amis),
# silambarasan,
# mayavanam.
# recognise
# (masayo
# choudhury,
# raven-haired
# worrell
# countess,
# (habib
# distilleries.
# predecessors.
# charity.
# cipur's
# sasikumar),
# jigsaw.
# engineer.'
# menon).
# head-first
# naeem
# nationally.
# shoshone
# dates,
# (shraddha
# nikhil.
# labelle
# fultons
# jerboa-like
# (marsh)
# who—he
# hume),
# (amitabh
# hennessy),
# cissy.
# mcewan)
# kullu
# buzzy
# (suresh),
# death—manages
# surfers.
# aughra.
# escarpeta)
# missile,
# [palanquin]
# cannabis,
# altman)
# transportation.
# otto,
# chaos:
# asokan),
# unaware.
# exsanguination.
# compassion,
# willard.[2]
# barassi
# kia
# norringer
# “comrades,
# chasers.
# miles).
# drawn.
# facilities.
# anti-hulk
# damini
# delia
# pavan)
# stingers.
# wuhan's
# silver.
# wishes)-
# (spears),
# fighting.
# recipient.
# homesteaders—a
# parenthood.
# digenerol,
# tie,
# bhupal
# clubs'
# uses.
# diwali,
# cash-strapped
# disguise)
# tangina,
# youngers,
# de)
# diper
# ajo
# (thompson),
# waited.
# ear,
# scare.
# iyar's
# pesticides,
# (ted
# capra's
# roster.
# (mamta
# solanas
# (hamilton
# plagiarism,
# library.
# frazee
# confidence)
# vikranth
# saudamani
# worker—that
# agriculture.
# dhanya
# lawfort
# shaughnessy.
# sai-yuk,
# alvarez's
# iit
# pender
# (eleanor
# wyn
# robotic,
# guerillas;
# animals'
# (jagathy)
# silence,
# overpowered.
# banu
# jaisalmer,
# relationship.
# settled,
# enter.
# siddiqui
# undefeated,
# (ibi)
# jefford),
# badle
# hartley),
# chandler),
# (lotte
# aardvark,
# genkai
# experiments,
# ishumaru
# fifteen-year-long
# cinderella's
# (ford)
# armada.
# o'hara)
# hoax,
# poster.
# umesh
# hasbro,
# baier's
# demeter
# gen.
# evildoers.
# deinosuchus
# sites.
# ivanovna,
# sivanna,
# dakota;
# hibernates.
# broke)
# foster-child
# talpade).
# aatish,
# fine),
# considered.
# kristina
# smash.
# payment.
# kati
# tribe,
# (smiley
# romana)
# germans),
# collectors,
# clavis
# soniya,
# brown.
# mueller,
# shortcomings,
# deepens.
# franco-mexican
# guitar-playing
# begum)
# ahmet
# nolan).
# siren.
# mars,
# woman;
# frederick,
# traced.
# sara;
# folded-up
# samantha/charly
# on-set,
# wyoming
# (lauter).
# mili,
# fudo
# szubanski's
# schoenberg
# leith),
# (stacy
# rounds,
# (torben
# mirren)
# soda,
# (kailash)
# sellout,
# yakuza's
# calculations.
# strasser's
# whitlam
# bhaer,
# kong),
# carmichael,
# corruption,
# blackfoot.
# on-site).
# ages,
# tutul.anirban(rahul
# brussard,
# jess's
# searle,
# moneybags.
# ambia's
# bathsheba.
# conscience,
# secured.
# basti
# nursery.
# rihanna
# neeta,
# dileep's
# zaporozhets.
# herefords,
# bale).
# kantha
# airport.
# hack.
# muthumani
# role,
# 1961.[2]
# andros,
# caspar,
# (nandha
# (madhabi
# suryan,
# sphynx
# f-16
# spear)
# usoltsev
# (tabu)
# lorne
# landmass.
# billings,
# chandu's
# fortress.
# briefcase.[2]
# (collin
# tiring,
# coronado
# uses).
# honorable.
# hallett
# vishnu
# 'house
# (greer)
# anyway),
# futile)
# narasawa,
# audie
# chakraborty),
# occupies,
# concealed:
# rumsey
# setting).
# tricycle.
# hiruko
# frisbee's
# miracles,
# mistresses,chopping
# fornication,
# reveals,
# madhuri’s
# dramatically.
# arbourfield's
# saul.
# chalker,
# valid)
# voting,
# bergère.
# purposes.[2][3]
# too,
# sommers,
# connery),
# (noelle
# kochadaiiyan
# tilly.
# duran,
# xiaochun's
# fissure,
# election,
# sebastian.
# tension.
# civvy
# (markus,
# rachel.
# loy)
# langan)
# eriquee's
# morelli
# (tone),
# siddhu.
# offsite
# kipp's
# madhurima’s
# wholly.
# talbot)
# khote-
# technologies.
# pie.
# jesup,
# caine
# luna's
# (100%
# controlled,
# asenath
# connor's
# kesslee,
# (claire)
# manhunt.
# (tex
# acs
# guiyang
# (samuthirakani).
# 'horseless
# frankenstein-like
# outlook,
# gang-controlled
# it...'
# undead.
# hamama
# glen),
# newspaper.[2][3][4]
# near-blasphemous
# sings,
# pathway,
# (rebar).
# darius'
# experiences:
# there!
# gajala
# frightened.
# taniguchi
# nanibala
# cbs
# draper;
# panchayat
# nigh-unmatched
# haynes,
# huntington's
# (lakshana)
# mountains—trying
# 'timid
# order'
# cavorite,
# influence,
# jeffcote's
# kimberly.
# shanthappan.
# barbarosa.
# greely,
# bengal
# host).
# hohner
# fiona
# houndour
# (georgie
# winch,
# dia's
# egyptians
# spratt
# ex-ips
# interruption,
# arturo's
# chasm.
# ex-wife.
# cunt.
# uninjured,
# sims),
# king.
# ji-woo
# snaps.
# rukia,
# unravel.
# b-2
# erickson's
# farming,
# kochurani
# mules,
# (ajit
# 40,000
# mercedes
# robby,
# brothers,
# more),
# brontosauruses.
# area.
# untouched,
# lazarus
# georgette,
# chumki,
# utopia,
# wood),
# tanya
# vivo
# kigata
# this.adi
# sonar,
# forteza),
# putney
# children.[3]
# donkey.
# goto,
# macbeth
# (shahir
# conditionally.
# seth),
# logical,
# shaan's
# rajapalayam
# nymph,
# courtier,
# galaxy-wide
# laxmi(anu
# greenwich
# 'milf'
# developer,
# 2017,
# mark.09.
# copyroom,
# landers
# fort.
# westwood
# differences),
# deploy.
# ensemble.
# dhruv.
# tobio's
# rakhi
# costume.
# fluently.
# force,
# pasupthy
# (mariette
# brandeston
# tramp,
# chances.
# (crazy
# handley)
# krabs'
# devised,
# ronet
# alps.
# (such
# xiaoyi,
# monchora
# marlowe's
# wing-chi
# initiate,
# schwensen
# (charlton
# eastman's
# mason)
# elba.
# simbu.
# mccann)
# (america
# half-jewish
# zoners)
# relative),
# denham),
# koizumi);
# davina,
# happens,
# stewart's
# stuntwoman
# (save
# budlofsky
# deepa's
# well-attended
# bhushan).
# petey.
# ginzburg)
# winners.
# wingman,
# chauvelin's
# school?
# kapur)
# commissioner,
# prometheus,
# shiuli
# fans.
# perkins
# baby:
# aldo
# foster-mother,
# felts,
# etherious
# raja),
# velazquez
# successfully.
# squareheads
# reins,
# cupid’s
# panic,
# jr.).
# neha.
# germans)
# scenarios.
# year-old
# sergeants,
# erica's
# preed
# tibet
# late:
# split,
# aboard:
# ak-47
# jae-young),
# florrie's
# plucky,
# barracini
# capitalist,
# achi
# concealed,
# prospectors,
# ruijuan,
# raghunath
# velkan,
# kamil),
# chang
# patterson,
# kill,
# truth:
# archer.
# yashoda
# miffed,
# schilts'
# mansfield.
# sooraj,
# appaloosa.
# dogsled,
# tangles'
# weapon:
# rajnikant's
# sparks)
# southwest.
# panettiere),
# heckart)
# jacoby.
# (zhou
# tarzan.
# culligan,
# asami
# complied,
# cartaphilus
# variety,
# scientist—also
# aaliyah,
# underneath)
# pilot/astronaut
# firefighters,
# guangzhou,
# nona,
# realises
# slum-dwelling
# keyes.
# servant).
# 1,200
# fascinating.
# benzedrine
# solitary,
# mitchell);
# forehead,
# brownies'
# ina's
# gluntz
# silambarasan
# capital,
# obi-wan.
# inhabitants).
# tess's
# pokémon's
# schomberg.
# dominick,
# butlers.
# transylvania)
# chakrabarti).
# anonymously.
# elzevir
# paynter
# still-comatose
# feat.
# previously-dead
# her.shylu
# levitate,
# catamites
# bo-hee,
# christmases
# donkey's).
# belqassim's
# averill's
# mccracken,
# escaping.[1]
# airplane.
# patrick,
# celebrities,
# domeheads.
# jazz,
# gas-fire
# marashi.
# hamunaptra.
# plankton,
# (carlyle
# ellie,
# mcfarland,
# brother’s
# hyer).
# non-chronologically
# freycinet.
# oxygen;
# (rajasekhar)
# julio.
# danzig,
# (rex
# mannix
# racket.).
# headset.
# beauville;
# tormented.
# turman),
# look-out
# robomen,
# others—lonnie
# mush-mouthed,
# annum.
# yankees
# ethan's
# 1880's
# (labelle).
# milly,
# rutledge
# spyker.
# kidney.
# robbers:
# xiaoyun,
# steve-o
# satsang
# (barnaby
# isfeld)
# vision'
# cardell's
# dad,
# ox-drawn
# midvale
# debra
# operation.
# cannibals'
# kell.
# (joyful
# margrete.
# dekker),
# fest,
# molloy
# phantom,
# coffins.
# grade.
# prix,
# ochoa's
# ohio
# c-130.
# sadanand)
# storefront,
# wargle's
# lyuda,
# civilian.
# law-breaker
# plainsville
# comparison,
# tim;
# ulfar
# spdc
# takeshima's
# rises,
# unjams,
# douzi's
# database,
# dog’s
# 60:00.
# satyamoorthy,
# (gibson
# oklahoma),
# biberman).
# rehman),
# contemplated.
# connecticut,
# saro
# accomplishments.
# giancarlo's
# emerson
# munder
# characteristics.
# anjana's
# gur
# ilango
# thailand's
# monks.
# annamalai
# croft,
# commercials.
# prohibited.
# rutherford,
# malfunctions,
# away!
# birth),
# gawain's
# genji's
# riya.
# organising
# (hsu
# imprint,
# jiazhen,
# poisoning,
# shinde).
# kiwi.[3][6][7]
# beverley
# homecoming.
# creator.
# anton
# drama.[3]
# m16
# position.
# holloway)
# adrenaline-fueled
# involved,
# terminated,
# gayathris
# disclose.
# group)
# archeologist,
# watermelon.
# –
# cavor
# tippy
# ammer,
# drury's
# matriarch,
# intercourse.
# (bailey),
# huda
# admonishment:
# lasya
# loco's
# sierra,
# brickyard,
# innocents,
# schiena),
# nell's
# savior.[1]
# sima,
# philip,
# jason,
# shyam
# hathaway's
# guarding,
# vanilla-flavored
# bhupati's
# grimes.
# mishka)
# aleksei
# neff.
# grave).
# cameo).
# foal,
# trawler.
# shivu
# boneless)
# publishing,
# a.d.d.,
# airman,
# grove.
# veterans,
# christianity
# beynat,
# chennai-billu
# re-alerts
# den.
# kobayashi.
# hijinks,
# deven
# (ike
# competencies.
# bhuvan's
# invincibility.
# ringwald)
# dorff),
# manmohan
# mayurakshi's
# mort.
# falling-out
# masayuki
# mayfield
# anran’s
# (red
# stone:
# kurt’s
# destructive.
# women’s
# prepared.
# escapade.
# winterfeldt)
# co-driver
# retirement.
# two-room
# illinois)
# explained.
# jacques),
# said)
# entropy.
# redgrave)
# tomb:
# bronson
# taramati
# started,
# (nani),
# lucian
# toto.
# davidson
# dingle)
# bohnen).
# roxanne,
# privileges),
# families;
# (but
# wang)
# (calloway),
# idyllic,
# eigenmann)
# kirshner,
# (stevens),
# cotton);
# better-known
# jhi
# bookseller’s
# tomorrow.
# 'be
# chilcoat,
# kneen
# breen's
# once)
# (morgan),
# gwen.
# vase,
# excursion,
# hing
# stepfamily,
# (pla)
# mitsuko
# yuki.
# monroy,
# mediocre,
# tzekel-kan.
# jaffrey).
# kikuchi,
# necklaces,
# see,
# merritt's
# cortina
# wager:
# (kyle
# african-american,
# ziao;
# pac-man
# unconfident.
# 8-year
# vishwajeet
# blackmoor
# hair-pin
# tourists'
# interviewer,
# gangster/don
# re-establishing
# meta-references
# lifespan,
# (janardhanan)
# gus,
# co-founder
# list).
# platoon-mates,
# houdini-like
# bale),
# ashok's
# jacob.
# turkey.
# sheltered,
# duct,
# 1913,
# candlemas
# skeletor.
# ship;
# juju—power
# boswell.
# costco
# xiaoyi's
# over-consciousness
# invitation.
# phobias.
# toby.
# ufo
# (matt
# (posani)
# mercury.
# yuen)
# capture.
# troublemaker.
# ripley
# flee,
# footlocker.
# filton.
# re-instated
# constable,
# leighton).
# lawn,
# origin,
# o'malley)
# dwells,
# denny,
# gained,
# (akiko
# ghana,
# jeremiah's
# laserdisc
# mori,
# (lanell
# georgia.
# amiri),
# strangers/admirers
# cawdor,
# ex-classmate,
# (jenette
# wentworth,
# trust.
# precocious,
# fardan
# chloroform,
# speymouth
# levis'
# thief.
# melchisidek
# bhoothnath,
# overcoat,
# succumbs),
# back-door,
# nelson).
# circulation.
# sabrina’s
# kulwant
# insistence.
# exam.
# (chick
# tiano
# pathak)
# thefts.
# afghanistan-pakistan
# kamala's
# kozma
# purged.
# pooja,
# incirlik-adana
# mcdeere
# groundhogs,
# magna-beam,
# reluctance,
# hesitatingly.
# indrajeet.
# (debenning),
# eirik,
# auto-driver.
# rainey's
# cello.
# microphone;
# galgo
# buddha's
# nicky's
# tim?
# asks,
# opera-themed
# middleclass
# sheffield
# (toolsie
# super-soldier.
# ptolemaios
# khajur
# telekinesis,
# numbers.
# yakuza
# maxton's
# sommers
# buchan's
# halloran,
# now-trained
# deschanel),
# riderless.
# arrhythmia.
# reservation,
# (oldman)
# emad,
# alessa
# bathsheba's
# prospects;
# locked.
# margate
# saïd,
# off-screen,
# clarissa—who
# exhaustion,
# sriparna,
# informant)
# (reece
# karunakara
# greczyn)
# (loudon
# katsuhide
# (gold
# corvinus.
# zhukov
# snowball.
# 1920s
# virtue,
# blood-connection,
# anyone,
# page.
# gladden—can't
# twickenham.
# viki,
# bhaskar's
# guo
# falcon,
# freeman)
# puppy.
# annabelle.
# justin
# iago
# pleasure.
# kartar
# plains.
# grasp.
# dog-track
# him.on
# mahler's
# helps.
# crockett
# (muktha
# father's.
# what)
# demand.
# time—something
# fancy-free.
# clockers,
# strengthen;
# converse).
# common,
# (brain
# strait-laced
# vehicle.
# archers.
# alley”
# buzz,
# paw.
# oedekerk)
# aarti.
# re-establish
# sprout),
# ikari.
# crichton
# drag-racing
# bonds.
# babbit's
# barton—tests
# kuzco's
# cyclotram
# namasivayam
# content,
# butan's
# abid
# bree.
# highcliffe
# vengeance.
# randy,
# mcculloch's
# comedian.
# rexford,
# muruga
# hh.
# to-and-fro
# of,
# harry,
# blake.
# priorities,
# anrokuzan,
# mangus
# blackbriar.
# grandview
# shaw),
# piglets).
# skipper)
# kanoonilal
# commission,
# pepper-spraying
# hon.
# chatterjee.
# rjs
# chaunduyt,
# hyun-jin),
# kana's
# madhumitha's
# dev's
# bullet-sized
# billie227,
# unsuccessful,
# blood-rain
# magee).
# ejiofor)
# 'connection'
# broken,
# (millar)
# simha,
# khairpura,
# lite,
# spotlight.
# glo
# crime;
# cammie
# cimmerians
# mcp's
# (kirat
# mori
# sattipandu,
# messner),
# okra,
# h.a.r.t.
# vomits,
# cigarette),
# boss”,
# initiation.
# cycles.
# douchebag
# jugran
# brady’s
# goldberg
# tse
# manhattan's
# chemistry.
# swipe,
# rushdi,
# barkis
# steadily.
# benefit.
# husband-and-wife
# martials
# femme-fatale
# earlier?
# akari.
# (tejus)
# classroom;
# amanpour
# 'singh
# nilavu’s
# sasi
# gant
# merrit
# (curtis
# (lalu
# bond)
# double-dealing
# monger,
# scouts—state-of-the-art
# long-hidden
# korean
# quarreling.
# ipod
# i'ww
# marie's
# bu
# pepura-metal,
# cruyff,
# nasone's
# safe-breaking
# parris
# imagined.[3]
# (murad)
# pimp;
# tagore).
# hunny
# wickes),
# sadako’s
# ex-private
# lung),
# aaron's
# toldd
# sow,
# tyler.
# rinaldi
# inhibitions.
# pampathy.
# bombsight.
# breakfast?,
# slinger's
# o'farrell
# ill-mannered,
# instructed,
# drown,
# f-16b
# sect.
# gatling
# barbarian/cave-man
# well-dressed,
# carveth,
# kenneth,
# him—but
# vandana
# botak's
# rescinded,
# (garrick
# deuce.
# mcdermott.
# subbaiah).
# cornelius,
# personable,
# marie’s
# god-king's
# lone).
# isao
# heart.[4]
# city.[1]
# short-cut,
# (elsie
# princes,
# charrington,
# 'sissy'
# alice’s
# dumbrille),
# practical.
# montcalm.
# pie?!
# kaasi,
# sculpture,
# robbie's
# surly,
# visiting,
# french),
# manchild
# notables,
# pia.
# kit).
# encampment,
# mehra.
# back).
# bleachers,
# appliances,
# communities,
# js).the
# i̇nanır)
# treehouse,
# isaac,
# kaplan),
# raymundo)
# canada,
# serbians
# by;
# queens,
# revoked,
# (x),
# usher)
# balu
# vizier.
# hooda).
# walters).
# garcía,
# 1937,
# ($92,000
# sophie.
# tough.[4]
# anomalies.
# bargee
# jiangjie),
# henshaw.
# malakai,
# kazim's
# mooré,
# simulpur,
# madumita's
# quinn
# papillon,
# mago),
# cathedral,
# caldwalder,
# anna'
# natalya
# thine.
# rasaan's
# re-open
# ishtar,
# cassel)
# kostya's
# sena,
# nandan
# (shira
# (sridevi
# showing,
# sudhanshu
# (vani
# 'rollo'
# spin,
# sutekh.
# blaine
# 19-year-old,
# (holding
# elvira,
# aaron.
# loretta.
# 10).
# carcasses,
# walsh,
# floor),
# rhetoric.
# nine,
# babylon
# uppilinathan
# finlay
# krishna).
# idlis
# pedro.
# human,
# vasher
# helsing
# pianist,
# died?
# court-martial
# disenchanted.
# craig),
# aatma's
# 'pecker'
# lampidorra,
# benched.
# protagonists:
# nanibala,
# jerome
# arackal.
# inoculated.
# tirupur.
# beidaihe
# petey
# warnerstock,
# sarika's
# believe;
# serepta
# (amazons,
# began:
# novel'
# sutton
# jew.
# heimlich
# pack,
# léonide
# perfidy.
# incident.[1]
# speedy.
# cigarettes,
# kira,
# jenny;
# ($1.9
# hyde-white)
# current)
# spina
# music;
# stilton
# doren),
# prabha.
# loan-sharking,
# once-promising
# patrol.
# seams.
# paces,
# all.
# day-to-day
# parineethi
# basel
# keiichirō
# (stewart)
# (keen)
# more)
# something....didn't
# airboat.
# juarez.
# cong.
# niki
# going-away
# mallick,
# get-well
# reels;
# bachelor'
# (sanju),
# morgado's
# power’s
# turkey,
# osric.
# lolita
# 1930s.
# hand?.
# quarry)
# in)
# b-17,
# leadready
# banerjee's
# snarl.
# distortions.
# mendez's
# gregory's
# shizuka.
# anjal
# using.
# trisha's
# t.c.
# meddling;
# half-siblings.
# love-letter
# (directly
# i've
# thrusts.
# herd,
# mcclintock,
# armour
# dna.
# camero)
# ayyadurai
# chhote,
# akarsha's
# gr76
# (eliot
# jelly-like
# bookstore,
# branz,
# apps.
# stopper,
# burwell
# whitey.
# lickboot
# narsimha.
# hunters.
# tables.
# told.
# eagerly,
# weak,
# him.they
# sreekumar.
# alvin's
# harbin
# affections.[3]
# precious.
# (pooja)
# cliff,
# fraternisation
# (hayley
# masterminded,
# event,
# colby,
# tuni,
# hermit-like
# shakaal
# amiable,
# fabian)
# sarthak's
# bomb)
# plain-clothes
# elise,
# garda
# granddaughter),
# gabe.
# anicurist
# tich,
# kosugi),
# crewmates,
# mcwayne,
# place),
# shruti
# (arjun)
# dauphin—to
# safecracking.
# sudheer,
# country.[4]
# note:
# synthetics,
# (shuichi)
# interloper.
# bedelia's
# sack,
# severn),
# manipulated.
# babji's
# rabies.
# blackbriar
# sachiko.
# (talia
# illusion.
# vigilante.
# holidays.
# on...
# fleet.
# soter
# assam,
# (isha
# vehicles.
# dutt)22,
# clear;
# facto
# corvinus
# victim.
# ambiguous;
# brady)
# ng)
# (sunshine
# little.
# arressted.
# ('cause
# cholera.
# choices,
# panza,
# foray.
# chang's
# luci
# (els).
# valkyr
# (fefsi
# biondi
# (chiranjeevi),
# practiced.
# rajasekhar,
# simple.
# donnelly
# gallier's
# muscle,
# aston
# pinter
# ex-convict.
# boyacky
# whittaker,
# wedding'.
# mackenzie.[2]
# mahua's
# previously.
# boussif,
# comic.
# ‘glasses’
# yoshikawa
# ram)
# seat;
# cotterill)
# smitten.
# incest.
# suspense,
# stingaree.
# kessie.
# clara
# weaknesses,
# bittersweet,
# culpepper.
# victims'
# (final
# sardarilal
# puck.
# (srikanth),
# stay-at-home
# frenchman).
# aidan’s
# duck’s
# duane
# knopfler
# crawls.
# after.for
# tio's
# mix-up,
# (you
# animal.
# matsudaira,
# jari,
# (rodney
# surveil
# vern's
# radcliffe,
# prism,
# leon).
# mandras,
# (tony
# (anr)
# representatives'
# bridesmaidiot
# bourne).
# amarkant
# machinations;
# client.
# villagers'
# died).
# selva
# rules:
# drosselmeier,
# janatha
# cabaret,
# fact,
# eggs;
# bull),
# vena,
# lebanon.
# corkill).
# feud.[4]
# distant,
# other:
# les.
# necklace,
# louis's
# mayne)
# asleep;
# laugh;
# fifteen-year-old,
# siblings/cousins
# nightmare,
# sojourn.
# phillips,
# billie’s
# brenden's
# upman
# (1962-65)
# rivals,
# geist's
# spent.
# other.[2]
# riyadh.
# fernandez.
# coaching.
# liszt,
# paru
# 10-minute
# olympia
# giridhar
# l.g.'s
# him.[6]
# sharon.
# vagrancy,
# hotline,
# kimon,
# built-up
# medusa.
# icarus's
# harsimran
# kal
# fiancee's
# dcf
# slightly,
# (ragini).
# (innocent),
# mirror),
# sakurai)
# villains.[5]
# italian-american
# williams
# brooks),
# evers
# reeser,
# guilt-free
# heflin)—is
# moscow
# hair,
# nash,
# atm,
# fcs
# to—through
# hatake
# lanes,
# spine.
# liz’s
# universes.
# (their
# petronilla
# balladeer,
# masoud's
# disintegrated,
# next-door,
# 747sp,
# jakande.
# laudable,
# man-beast
# kanga.
# shivayam
# gowtham’s
# named)
# lovesick.
# sacrifice.
# spear-bearing
# loomis'.
# free)
# schmamm),
# crone,
# bruges.
# connections,
# (eamon
# intentions.
# xenolinguist
# redress,
# diyala.
# balcony.
# bta
# greville,
# deuce-and-a-half
# amedeo,
# activists,
# convention.
# presentation,
# times),
# karlsbad;
# ikaros'
# shovanlal
# mccloud,
# babies,
# agamemnon,
# o'banions.
# vaishnavi
# notah
# 'evil',
# (allen
# druids;
# spages
# c99
# fredi
# cortona
# nádasdy
# mayfair.
# connolly's
# bradlee
# tristen's
# (webb),
# homeland.
# first-class.
# lindsey's
# (literal)
# holotik),
# nanahara;
# singh
# (sally
# half-blind
# (dervis
# notorious,
# unkind,[4]
# mcgargle,
# isabella,
# prisoners.
# wildlife.
# preston),
# wiser.
# gajsingh.
# uncertain,
# (brandon
# wnw
# mcness
# run-down
# decks,
# (mom
# williamson),
# cynthia
# day.[8]
# jabba's
# (vandana).
# haunting.
# (howie
# zamperini
# edgar,
# (woodward),
# handicap.
# prill
# (kossoff)
# saxon
# gto
# club’s
# abuse,
# dr.jackson
# karimganj
# pawnbreaker's
# inexperience,
# da
# wow),
# fumiko
# leopold
# killium
# (ross
# city-sized
# (regan
# 'mary'
# amor
# oorials
# कसा
# poem:
# pins,
# tsuguri
# (indraneil
# husband’s
# gair),
# heywood),
# shawkat)
# in-laws
# s.p.
# mcgregor),
# verse.
# suryam.
# ekam's
# cup!
# interment.
# noises)
# carolan's
# grave/if
# beckmeyers
# thirupathi’s
# shan
# werewolves'
# (shantilal
# indigo.
# simran
# zarcoff
# nikon
# andersonville,
# goblin,
# gutierrez
# industry;
# flees.
# buyed
# ranjeet
# heidelberg.
# spikes.
# twenty-third
# vinash
# orm
# (wendell
# (toby
# dean-z
# fencing.
# bride-to-be,
# migs
# festivities,
# taft,
# hesitance,
# (hebah
# merchant.
# boom.
# impression),
# dominick's
# questionable.
# mason,
# srinivasan,
# smalls,
# black-marketeering
# pyper-ferguson),
# mushizo
# sang-nam
# lingamurthy).
# 20-year-old
# undirected,
# courtesies,
# nso
# passages.
# taksim-bostancı
# administration.
# ica.
# shell-shock,
# dvds)
# arcati
# (whit
# triangles,
# (ketchup
# snow-white
# houses.
# pazuzu)
# bargavan
# bullied.
# sreeraman)
# traumatized,
# achilles'
# dead:
# remark,
# churchgoers.
# friday.
# lomax's
# yoko
# (garrett
# dakota.}
# cpr.
# drowns,
# cranston's
# (purnima
# cc&sj
# buckenham
# priyaa
# sickness.
# sushma
# (daniels
# ravi).
# half-native
# shaan,
# rajan;
# mui)
# iv,
# rené,
# silas
# troubadors
# past,
# telegraph,
# poonam's
# 'bhabhi'
# sonia.
# oxcom
# eligible,
# kurahashi,
# tuatha
# pyromaniac;
# sub-basement.
# barrientos'
# conrad),
# 13:20,
# shami
# (boone)
# baylock
# brennan).
# repute.
# taraji
# karina,
# gurfinkel
# adaline.
# natsuko
# menahem
# irving's
# tamegawa
# gabby's
# chester,
# terrier,
# again,
# intan),
# bhoond
# inserted,
# (mussolini)
# papa,
# carolan,
# jailhouse,
# glynnis
# antoinette.
# (christian
# paulus
# 'representatives
# 10½
# creighton's
# delt
# huey.
# siddhi
# murgatroyd
# hollywood-bound
# automobiles.
# rodanthe,
# murder-suicide.
# randle)
# bkn,
# (leading
# kanhaiyalal
# demon-headed
# scorpion)
# youngster,
# 13th,
# serano)
# hitman.
# arbitron
# bijli,
# (cargo)
# blakeney
# lasher.
# presnell)
# bulgaria,
# (subhendu
# personal.
# gasoline,
# boxer.
# burdette,
# jindal's
# bailes,
# helperman,
# laxatives.
# (jealousy).
# zamindari
# vindicator.
# acnologia
# lurkers;
# charlaplly
# hutcherson)
# ayya(saravanan)
# ratan.
# shahir).
# mesquiteers
# papers)
# wanted!
# prynne
# decanter.
# (gary
# kisu-mu,
# hagg,
# streep)
# narasimha,
# politics,
# inept.
# elroy,
# tourists,
# reader.
# archana's
# troubadour.
# (prunella
# steamer...affecting,
# kibagami,
# rowlands)
# 1645,
# freighter.
# warlock.
# magical,
# (sharat
# heard,
# (mildred
# whitney
# palumbo)
# bhaduri,
# bascombs
# tzekel-kan,
# barley,
# wake.
# stress-induced
# sub-camp.
# sikh
# lindhagen
# malaria,
# hints.
# dissipated.
# (curtis)
# (even
# vyner),
# (edna
# townfolk,
# deacon)
# bascon),
# miles's
# atheris
# closed-space
# ives)
# bakhtavar
# musgrove
# (lindsay
# patron.
# hulland
# anybody.
# un-dead.
# (rahman)
# love/hate
# punyalanmar
# gulshan
# bank-employed
# mla,
# lifestyle...
# van;
# still-burning
# (couto
# purgatory,
# axle,
# jugular.
# owl-bomb
# viciously.
# “what
# kay
# armoured
# realtor.
# roopa.
# weyland-yutani
# kassar
# cringe,
# rodders,
# english-language
# guys.
# blitz,
# pottery.
# batteries.
# kunis),
# jeong.
# matches”
# aune,
# amrita's
# erickson).
# consuela
# comedy/drama
# alvin
# brochant
# kidder),
# hematoma.
# latimer
# (yang
# miri's
# dispersed,
# two-dollar
# rangers;
# grannie.
# admiration.
# maddox's
# twin-sister.
# onerous.
# bhaer.
# (vijeta
# decision-making,
# kung-fu
# cody
# salon,
# (conner),
# schoolmates.
# 18-pound
# ago,
# (robert
# adi
# lassan
# genevieve
# renfrew
# bthuthdy
# researching,
# deusen.
# rishi)
# “maybe
# sphinx—an
# viswambharan's
# bridger,
# photoshoot,
# clarification,
# starbottle
# saakshi
# augie;
# wheelchair.
# raju)
# interrogation.
# siva's
# vortex.
# gowrishankar,
# baby—to
# even-handedness
# diner.
# karp
# defeated—the
# plain.
# merrick
# gorath's
# anju
# patrol,
# allergic)
# philanderer,
# kel,
# p.
# lewiston,
# zaidi),
# infectant
# 1911:
# hirt)
# finkel,
# parents.
# gas'
# sethji
# supt
# bobo;
# cag
# hollister
# ostracization
# (arman
# round-up
# pate)
# rutherford),
# notepad,
# jarvis;
# revolvers,
# augustine's
# parma's
# accedes.
# prakash.
# marker.
# rusizi
# curses,
# wei),
# karlstadt
# convention,
# pasts.
# compartments.
# kulakarni)
# comic,
# mary-mengele,
# teen-aged
# ulmer
# turtle),
# chittenden)
# high-decibel
# simón,
# grudges,
# satan,
# barak),
# thee.
# chinni
# (parineeti
# (real-life
# (nikki
# inder
# szalinski
# sprit,
# prologue);
# point,
# masters.
# r.i.p
# (majors),
# leaders,
# transported.
# asteroid,
# (ulrich),
# commodities.
# curley's
# winship.
# qwark.
# balan
# jarboe's.
# fa.
# beston.
# honeymoon,
# gateshead
# (vtv
# hyrax.
# (lyn
# siddiqui's
# openly—in
# fresh.
# holborn
# layman,
# catchers,
# revathy
# confluence.
# safekeeping,
# second/third
# yakuza,
# re-established
# henreid's
# grover,
# tenement,
# chick'
# kesslee
# butt-head
# tomb,
# guilt-ridden,
# court-martial,
# lupo,
# rocky.
# (penélope
# 1959,
# lars,
# poojary
# supporter,
# gym.
# rotors,
# indirectly.
# skin,
# prasad)
# conjunction,
# natured.
# nadia)
# later),
# bishop)
# coffin.[1]
# find.
# patrolman,
# yadav),
# clumsiness.
# marx
# warden)
# coward.being
# suspicion—there
# pep-talk
# kendal.
# kinetech.[4]
# burmester),
# (brodus
# comrades-in-arms
# drive,
# quantana,
# pleasures.
# mathis),
# strictland's
# kath,
# (rajini
# built,
# carnforth
# pakru),
# comacho
# well-endowed
# cavewoman
# prickett's
# maddalena
# marantino,
# ten-year
# winner-takes-all
# yūko
# lina's
# (lizabeth
# rendezvous,
# borders.
# outlawed.
# wahlberg),
# annually-held
# kaname),
# investors,
# (kerry
# jerri.
# pekwarsky
# sherbondy
# knocko.
# unperturbed.
# eleven-year-old
# bangarraju.
# (edmund's
# kenneally
# shailu,
# lali,
# moose,
# owens),
# (sanusha)
# anticipation,
# satire,
# (smith)
# esther,
# nose,
# north,
# price)
# self-pity.
# i̇vedik
# nastanirh
# xiaoyu's
# grown.
# slimer
# acat
# rollison
# surrender.[2]
# thracians.
# story,
# browbeaten,
# 3.)
# strobie
# pitamber
# max)
# boko
# it?
# flay.
# bury,
# nightmares,
# alponian
# fresno,
# kober)
# screaming.
# notices.
# genius.
# constantini
# serneena
# (mahboob
# gunsight
# kathleen's
# candyland,
# spirits'
# money-wise,
# shivani.
# metre
# stoddard
# maeda)
# cowers.
# barrow.
# issue.
# greczyn).
# alvin).
# route).
# jurgis
# hope-filled
# wings),
# wolbert)
# volk)
# springs,
# marisa's
# nedell)
# shahabuddin
# aggressors.
# zooey,
# (jimeoin
# canaan.
# (nana
# raylene,
# sistah
# matvey
# psychologist.
# poppy—return.
# ching)
# complaintee.
# flippen)
# bogart)
# (nishi
# disgust.
# since-abandoned
# 'feathers'
# him)
# done-over
# inter-rokinental
# v70
# enigma,
# lessing
# energy—to
# sedative,
# nerv,
# (baharov),
# binford
# animals,
# medic.
# vettupuli
# roy
# delusional.
# madhavgarh
# lamont,
# lahood's
# defendants.
# peil
# chronos'
# yazhini.
# spa.
# cigarette.
# eisteddfod,
# wendy;
# counselor,
# bare,
# batz—an
# maan),
# rufe
# schellhardt)
# longevity.
# (led
# quasi-sentient
# bearpaw.
# farah,
# maurice,
# angelo's
# ruiz)
# (barry
# complicit.
# (leon
# (francisco
# sadness.
# afterward).
# moriwaki
# riette,
# kabaddi
# birdcage.
# town.[2]
# oliver
# singing),
# twenties.
# sneakers,
# ukulele,
# bennett's
# shrunken,
# pelé
# gilbert,
# beulah's
# elders.[1][2][3][4]
# ephraim),
# relaxation.
# x-117
# picerni).
# anomymous
# backpack,
# railroad,
# lou
# tydfil,
# (streisand),
# tremendously,
# maharashtrian
# mccaffrey
# five-minute
# barnacle!
# con-artist
# fatoush's
# pimpernel—actually
# mugilan
# bank-robbery
# asylum.
# simbas.
# love.maha
# small.
# artie
# ascend,
# thoogudeep
# agency.
# lavinia
# upsetting,
# drain,
# ageyev),
# gajjar),
# anna's.
# kamla
# d.e.b.;
# slurs.
# disappearing.
# oss
# wore,
# transporter,
# roc),
# trent,
# 20's;
# (musskan
# mutate,
# bhalla)
# ursula's
# (sayali
# asura.
# blocker.
# caroline
# british-italian
# thirty-four
# davy
# landau),
# daru
# garuga,
# namasthe.
# kanmani's
# surreptitiously,
# (hariraj),
# referee-in-training
# (nayantara),
# dispatcher,
# brandt's
# tolga
# tear—alternate
# limbo,
# payday,
# pearson).
# hammerstein
# tardis,
# movies!.
# jos,
# iki,
# yogendra
# herod,
# nevermore.
# ash,
# chiko
# sindhu
# hoggins,
# judo.
# atf's
# herrmann
# hypnosis,
# obsessively.
# rasulala)
# johannesburg,
# gnt-0000
# lore.
# (goring),
# $25
# stereotype.
# piano-playing
# hai.
# (fahadh
# (patekar)
# phenomenon,
# preetam,
# relatives'
# auron,
# glimmer,
# best.
# man'
# summer!
# nris
# shoujirou
# lakshman’s
# base;
# cates.
# channing,
# intercourse's,
# snipes),
# dundee's
# father-in-law's
# kidding.
# sydney's
# insomniac.
# scotia,
# ironic.
# shun.
# separatists'
# keller);
# network-based
# 1940,
# syms)
# (cvn-65).
# attache
# relenting.
# angel)
# drayson,
# die:
# plague.[2]
# dollhouse,
# katsov's
# (federico
# lang
# aurélia.
# postmortem.
# tamerlane,
# rancher.
# (lowell
# (rituparno
# whos,
# masseur,
# out-of-focus
# borg),
# scooter.
# cheena,
# pose,
# doherty.
# happily.
# masoud,
# motorcycles;
# binoculars,
# tf
# (bren
# disagreements,
# malagá,
# mahima
# pimp,
# photoshoot
# marvan
# shirtless,
# motor,
# record.
# vamsi,
# manticore,
# stromboli's
# woode,
# captain),
# clanton,
# bikes).
# involved.
# culprit.
# muffy
# hiralal
# limehouse,
# weathers.
# (sex).
# marzack
# goutham,
# (singing
# steckle
# (chaykin)
# bradford
# opened,
# angeles.[3]
# dr.anughatak.
# retraction.
# visions,
# café’s
# seeker,
# flatmates,
# maddow
# cue;
# nunataaq,
# bunkers.
# marrero)
# infatuation.
# wils—one
# lucybelle
# kaul),
# kuttanad,
# etar.
# stole.
# reject.
# (予言魚))
# (raquel
# yazmalım
# kathyayani
# wallace,
# archimedes
# truth-revealing
# heinzman
# clobber).
# chowdhury's
# bhanu's
# blacque)
# offspring.
# merivel
# lampshade,
# frye
# obsolete.
# gem,
# soul-mate,
# control,
# greer).
# cadet,
# (bathe
# son-in
# gulch,
# seemingly,
# londoh)
# remarry,
# lucas'
# housing:
# evil.
# andre,
# poison,
# halt.
# (mckeown)
# unauthorised
# (tejanos),
# fowley)
# [adora]
# lally)
# sympathises
# 65th
# fast;
# lennards
# marni
# ‘ek
# aduramo),
# repeatedly,
# chaney,
# mylene
# years)
# juno.
# ruled.
# siegal
# deck;
# nozumu.
# jamaican-american
# dzb
# cymbals.
# housekeeper.
# kancha’s
# finney)
# (miles)
# message:
# autopsy.
# walt's
# payano)
# rukia's
# giftwrapped.
# lalbai.
# sensibilities,
# agrees.but
# 42,
# bagheera's
# ingredients.
# duel.
# firearms)
# (kishori
# tamura
# coffee-bar
# asuravithu
# shattuck
# morita
# sub-editor
# (hazeldine)
# fanfare,
# narwhales
# (gayathrie
# hidden:
# court)
# (divyendu
# music-hall
# minhas)
# bolivar,
# strate
# owl,
# stuart),
# dalli),
# lindhome),
# disperses.[4]
# nonyela)
# re-runs
# jeezy
# leukoencephalopathy,
# camino
# seward.
# kailashnath's
# hideyoshi's
# minotaur.
# earth!
# morillon
# freedom,
# heder),
# incredulously,
# sheiks.
# duessa.
# degroat
# wharf,
# shiuli.
# shajon)
# kolkata.[7]
# (chiranjeevi)
# beulah,
# dino,
# pre-world
# bankrupt.[5]
# sabor
# hugging,
# 3:10
# skates,
# leafie's
# chainsaw,
# hachita's
# gambling-addict
# bhagyam's
# ahead—sees
# discreet.
# ldf's
# sarcophagus.
# insiders'
# (ma)
# investigators'
# toichi,
# candice
# ofw
# amphibulos
# institutional-sized
# celeste.
# plotline
# merchants.
# ensues:
# (chellapa)
# u-haul
# (bates)
# frazee,
# malayalam
# torture,
# tavistock
# charles
# suzi
# well-armed,
# keach),
# marenick
# muthazagu's
# wombles,
# rawlings,
# disrupted,
# “gunin”.
# keaton),
# balaji's
# men.[4]
# 1917,
# sermano.
# parlour.
# khemu),
# dimaggio)
# dissenters,
# ombre.
# caer
# (henri
# jubilee,
# zygon.
# smits)
# outdated.
# rhonda,
# (rati
# chakrabarty).
# linked.
# yero.
# orissa-based
# businessman,
# shine,
# tobgyal,
# red.[2]
# subrahmanyam),
# welch),
# aburame,
# vibrating,
# (mills),
# nelson.
# torgo
# sanderson),
# mclovin.
# gooder
# isaac
# copley's
# great-niece
# malcolm's
# xiong.
# wigan
# couple;
# faqtooni
# attic),
# confiscated,
# (cummings)
# residency.
# jawaharlal
# hydari).
# simbu,
# loyal.
# sedley
# jumpers'
# witkin),
# sherawat).
# unwittingly,
# bojack.
# makise,
# octaman
# stricken,
# (balayya).
# deerfield,
# susan's
# murderers.
# uday
# angelleena
# (1963)
# declared.
# ipad.
# #1,
# yiwei)
# (vijay)
# $20,000,
# manami,
# kathadin.
# sterlings
# change.).
# (latino
# insemination—but
# aquinas’
# penavega)
# time...
# (lakshmi)
# body)
# thoughts:
# playboy,
# other—maggie
# mangalpur
# forcefield
# diagnosis,
# utah's
# heathrow
# shoot.
# things,
# cherkov,
# (nadira)
# mahon.
# (alokananda).
# benson
# eject,
# (ving
# offscreen.
# serna),
# slain).
# zhi'er.
# them-self
# josephine,
# mamoru
# sruthi,
# sweater,
# sreenivasan).
# mouth,
# undamaged.
# sick-little-well-girl
# ortiz,
# gestapo-like
# crowsons
# accused,
# gaxton,
# sinbad's
# nabbed.
# swinger,
# (pearl
# ella.
# (arliss),
# cici's
# perpetrator,
# lucci
# duraisingam
# shingo's
# cesar,
# self-assertiveness,
# wutai
# mid-30s
# seemingly-irreproachable
# beckenham
# threatened.
# reddy
# weil.
# irina,
# walks,
# icu
# garfield)
# johann.
# avengers:
# chuma
# gubbi
# willard)
# matures.
# peralta),
# taryn,
# (petersen).
# noisemaker.
# wanima
# hammersley,
# post.
# tamara's
# apprehend,
# psychos,
# favorite).
# “romeo
# 'why
# archer),
# hüseyin
# years[3]
# arceus
# shabnam
# tyre
# states.
# cnn-esque
# baskar‘s
# justifiable.
# thamarai.
# cuda
# travers)
# 148.)
# chart-topping
# us$400,000
# labyrinth,
# (himself).
# clarinet,
# evers)
# bored,
# canteen).
# chellappa,
# louise,
# govil).
# confederacy,
# lepke,
# scott).
# blue-white
# depicting:
# gun-slinging
# glock.
# (maribeth
# gates'
# scrapbook,
# sanz),
# nandakumar's
# denials.
# stalder,
# sister).
# seen;
# briones.
# bbc.
# unni
# danube.
# timer.
# rocklin's
# magicians,
# rakhsha
# subiaco
# gamsey,
# sathya.
# discuss,
# cook).
# mitchy,
# abduction.
# perkins),
# chetan)
# money.[3]
# nara
# paul,
# west-indian
# seattle—where
# kraven,
# trans-am,
# pleases,
# captain,
# (wiser
# danielle,
# mate.
# darrow),
# leung)
# vicente)
# zero-x
# fasano)
# pneumonia,
# pichel),
# botha.
# over-the-top
# re-educate
# lattimer
# chuck,
# (maternal
# colombo
# bug-eyed
# kobling
# grimly.vijay
# renege,
# boullée.
# decisions.
# (nakul).
# this?,
# barris.
# regenerates.
# parvana's
# comp.
# indian
# laurie's
# ommadon,
# cocktails,
# koga
# gajsingh,
# (pan
# burglar,
# (carmouze)
# (rafael
# kenter,
# calder
# malco)
# janaki
# dignity.
# less-well-groomed
# brumby.
# (bogarde).
# mathai
# nicodemos,
# haines's
# thakkar
# fanatic.
# canfield.
# morland,
# sunk.
# lugo
# back-up,
# mia—her
# chicken-hawk
# knauer,
# one-week
# ruined,
# arkansas,
# fudd.
# nests.
# aishwarya.
# cope.
# leah
# bascom,
# medrano)
# gugino)
# renji
# giveaway.
# chauhan;
# playground.
# hagen
# yorkshire
# disappointedly
# verner,
# capitol.
# nguyen
# sutphen
# gaki
# $60,000,
# maitland's
# minded.
# atteron,
# (susan),
# penny’s
# shamik
# sprinklers,
# torno
# shock-wave
# rangarao
# hopkins'
# phobos.
# mccloskey.
# hollar)
# rough-house
# pilgrimage.
# big-box
# buddy.
# assimilated.
# (willy
# learns,
# school),
# daughter;
# (sarita
# ufo's
# monami
# shore.
# o'houlihan
# townsmen,
# plain-looking,
# replicating.
# age-old
# athiras
# keith's
# kappu)
# sotheby's
# bypass.
# birack
# detectives.
# indiscriminately.
# kerwin),
# vlad
# quanah
# clique—the
# athira.
# indianapolis,
# elsewhere.
# (n.
# rajkumari,
# sey
# mellon
# asakawa,
# brand,
# grogan.
# jujuy
# elan's
# molloy,
# chika
# (tarapore)
# (mary-kate
# ritch),
# nguyen,
# (tota
# award,
# budar's
# siddharth's
# candide,
# trashed,
# (jürgen
# hyo-jin)
# itchenko's
# zionist
# experiments.
# palme
# bell).
# curfew,
# ozaki
# fighters'
# cocoons,
# mysore.
# (humayun
# flagstaff.
# blackbriar,
# autogyro
# sravani’s
# remo’s
# hewitt
# anglos,
# syndrome.
# wichita
# switchblade,
# weakness.
# tamsin
# gomorrah,
# sixteen-year
# selenites.
# brody,
# 'michelle',
# jerry.
# parents's
# warrier
# grip.
# (sukanya),
# battlecruiser
# traylor),
# flores
# bill’s
# selling,
# hamish's
# norma,
# emiliano
# lashing.
# supercar,
# outcomes.
# tyrannical,
# repressurize
# fantastical,
# alba's
# dominating,
# bahni
# katchemu
# magician,
# head-on;
# cole–so
# buck)
# (offscreen)
# avon,
# dunderhead,
# isha
# pipeline,
# chamaco,
# austrian
# thug-for-hire,
# lakshminarayanan
# abby
# marcie
# rutledge's
# still-summoned
# himesh
# shout,
# proceeds.
# (chanchal
# detective.[1]
# handi.
# d'arcy
# flooded.
# plymouth
# sports-photography
# imaginable.
# secretary.[3]
# wrists,
# smike's
# pre-80s
# buttocks,
# complicated.[5][6]
# arti
# hodja
# jules's
# hrothgar's
# (gokul,
# packham
# gas-powered
# cartoons.
# locksby
# hands)
# court-martialled,
# (carey),
# (cordy
# frederica,
# lospecchio.
# mariella,
# party-goers,
# vermont
# kazama.
# revolvers.
# mme
# sobbing,
# entourage;
# edachena
# 1936,
# angus'
# jyothi
# kasim
# standing,
# carlos,
# cactus.
# kinyon,
# himangshu
# angad,
# superbark
# gordo's
# speaking...
# anthony,
# sukhorukov)
# bee.
# smecker
# water-locked
# sriram,
# jiali)
# zughan,
# kleitz
# buck.[2]
# hendrix).
# ice-skating
# glass.
# plot;
# friend—an
# armor.
# jar,
# macgregor
# dorian,
# oretzia
# rock-a-bye
# elixir,
# rex,
# (markland)
# hanzō
# penguin.
# peoples's
# shudadah.
# (eason
# knyazev
# rege's
# unburied.
# teacher);
# (pesci)
# marielle,
# farmers.
# children)
# isolated.
# prospector.
# shirdi
# of?
# pearson)
# (leanne
# subways.
# rabbits?!
# truffles.
# hordern).
# cadillac,
# papagallo:
# (jayamalini).
# laredo,
# jones).
# isay,
# newly-weds.
# cerveteri,
# t.j.,
# pedulas
# (patricia,
# mission).
# help),
# homosexual,
# parnell,
# erlynne,
# broke.
# (aden
# gen
# fillion)
# streaking.
# vilain
# to)
# nicastro)
# sen),
# mexican,
# vulcan
# combustion,
# mannered.
# island),
# threat.[5]
# (warden),
# melancholy,
# arora),
# dern
# nightstalkers's
# thing).
# chameleon,
# skinhead,
# rudolph
# anthony
# cofferdam,
# nolan),
# halley
# ratajkowski,
# team,[1]
# tendons.
# wife),
# ritter
# clashing,
# gymnastics.
# yelling,
# nanette
# goldfishes.
# iii)
# bosses,
# threats.
# remar).
# (dewey
# (bilal
# emory,
# (malone)
# bangor,
# julie.
# floor;
# sarathy's
# time-traveler
# (bedford)
# $2,500
# dishwashing
# hand-to-hand
# baadal's
# achievements,
# cloris
# farmer)
# xiang's
# brenners'
# tsu),
# banned.
# restored-to-humanity
# mario
# identification.
# james-younger
# addiction:
# replies:
# factory,
# (sheela)
# medha
# loggia)
# santa-clad
# effective,
# tased.
# supporting)
# colva
# alamogordo,
# blacked-out
# practising,
# websites.
# bettencourt's
# rains).
# fredrick
# wicked.
# horace:
# reiko's
# scoutleader,
# mccomb.
# out.[2][3][4][5]
# (nicolas
# pre-degree
# vrooman)
# affection.[12]
# lisbon
# (anupam
# resentment,
# ann;
# angelique's
# craft,
# tamara,
# kobita
# comrades-in-arms)
# outcry.
# ozzie,
# junk)
# rajashekar,
# vishi,
# storm)
# gans
# morse)
# (subhashree
# ernakulam.
# (zee)
# bus;
# touchetts'
# sodomy.
# revelation:
# zheng,
# amos,
# horton)
# qaeda
# nylon,
# busey),
# creek,
# non-cooperative
# esakki.
# talos'
# moreton
# dues,
# (lindy
# creedmore
# horses,
# loving,
# ruffians,
# eve's,
# dagen,
# zombies)
# greene),
# boley,
# macclaggan
# (jodelle
# dunn
# daitokuji
# abilene,
# tracks.
# barris
# knowles
# c-4
# dhamradeva
# legends.
# anti-castrists
# lesbian,
# rossington
# bleuer's
# lauria),
# sakhina's
# hero’s
# brothers:
# this?'
# ramona.
# deicdes
# tattoo,
# sports-themed
# bijuriya.
# tortured,
# (stunt
# pavalakkodi,
# (granger),
# earned,
# role-play
# murders.[7]
# brog
# “bird-watchers'
# cartels.
# sfpd
# freeze.
# (kanan
# li'l
# katharine's
# mission;
# dhanda
# zona
# soweto,
# vinny,
# mistake.
# vasu,
# program,
# cellar,
# (sid
# feast.
# blood-sucking
# kevin,
# lilulu
# bullies,
# flute,
# sopida
# tail)
# talley),
# chelsea's
# (guan
# rift.
# figuerola
# wallach
# summit.
# bornova
# iim
# 'drossmouth',
# agrabah,
# (aparna).
# dream',
# hesh-ke
# aoyama,
# miriam,
# arcati's
# mckinnon
# campbell),
# (sakthi),
# prydain,
# pruitt,
# manzi,
# crewman,
# yatsu
# lavender.
# lloyd
# merkerson)
# quentero
# theater.
# motel,
# me-mania's
# (i've
# dorset.
# jonak
# ayasaki—hayate’s
# hatem).
# glimmer).
# blow,
# soater
# londoner
# mittens,
# reiner
# breton)
# rupa
# waxted
# gather,
# disks,
# attempts:
# redlund
# charlene
# clutesi),
# accident.and
# bernardo:
# daash.
# milvaine,
# vijay,(mukesh
# sitara's
# otis's
# kottipattinam.
# trip.throughout
# kumalo
# richardson's
# sprague
# auto-rickshaw
# callie).
# long-gone
# tases
# incense-choked
# (radharavi),
# cda's
# cheese/iron
# zebedee
# mobilisation
# feed,
# mukoda
# (allan
# marge's
# masami,
# milner)
# completes.
# (keenen
# rossiter
# text-to-voice
# comes.
# whale.
# hamilton),
# debuin
# qiuyi,
# moon)
# attack),
# given.[1][2]
# b-phase,
# sardar,
# safer.
# plotz)
# (imf),
# hay,
# (krushna
# nas
# bean-counting
# ajoy
# shaving;
# callistratus,
# dcp
# newman).
# zeynep,
# (geno
# hooligans,
# agartha
# benson)
# au
# 'corpse'
# degüello
# moon!).
# benes.
# j.;
# hemachandran,
# zapateado.
# c1860),
# joint).
# (bhatia)
# invaded.
# irani
# miracle,
# steven,
# leila,
# chawla,
# finn
# yamagishi
# miran.
# occult.
# punishment.[6]
# hopes)
# degan,
# (bhanupriya)
# 1970,
# kagaz
# levitations,
# behind-the-scenes
# slr
# airship.
# sullen,
# lantz.
# lakshman.
# theo
# basu)
# (clearly
# fearlessness,
# (girish)
# moretz)
# fievel
# adores.
# yes!
# smartmedia
# satanists,
# buchi
# unexpectedly;
# bergen),
# quran.
# moosa’s
# ranigaon,
# marry?
# susman
# nilofar,
# duncan,[10]
# vasanth
# decanter,
# sudhakar,
# guy's.
# (shakeela).
# kaminsky's
# ever-exposed
# hui'e's
# gessner.
# lady.
# (sadha
# retiring.
# offers,
# 'sixpack'
# south?,
# comes-of-age
# (rez
# letscher)
# intro)
# alissa
# deucalion.
# (stella
# (meshach
# litel),
# platinum,
# shinji.
# sealing,
# (kirby
# falburn,
# york),
# amphitheater.
# tsuji)
# 17-year-old,
# models.
# mei-chu's
# nandita's
# ostrowski
# velociraptor
# homeowners-association
# susheela
# ahead,
# macroon
# bachelor'.
# chesapeake
# kiggins,
# jeanie.
# bitchy.
# manganelli's
# impossible.)
# woodswurch,
# fuqing.
# bultitude.
# right.
# immedialety,
# narcisse
# mijan
# contest;
# confinement.
# wix,
# mcp.
# gant.
# wright)
# co-owner
# overstreet,
# beller
# patch)
# breslin-clark,
# stille)
# sands's
# sanford
# consequences;
# alfie's
# applause;
# “them”,
# utpal
# greensmith
# prevost),
# chotu
# cb-cid
# rader)
# (raghava
# fiametta
# wink.
# (yuji
# dimmock
# dewitt
# destroyed.
# feisty,
# house)
# catholicism.
# original,
# l.a..
# corfe
# buchan
# man-beasts
# drive)
# protects.
# prago,
# tse-ho
# plana)
# bar)
# 1863,
# dushku),
# appala
# naani.
# childish,
# fifi
# scrat
# investor.
# gordal
# elma
# cyndaquil,
# security-camera
# mcgraw)
# sky.
# iceman.
# lewicki,
# consummated.
# vijay.
# kumite
# cal
# leap'
# him.ram
# flowers,
# all;
# borgadars
# shōnagon's
# sell,
# gershon)
# nedungnadi
# asano,
# rainfall,
# self-styled
# surprise;
# arivazhagan,
# jeannie.
# cotton,
# hoi
# re-engineers
# springfield,
# petersen
# karlsbad,
# injury),
# ps,
# (hall).
# (mohana)
# hammond,
# asrani)
# crater,
# udre,
# court-martial)
# newsreader/announcer
# shopkeep
# stereotypes,
# ring,
# delores.
# pakistani
# balasubrahmanyam)
# free-for-all
# tone).
# slaying.
# ethan,
# place,
# (thakur's
# deborah.
# (owens)
# spike’s
# doldrum
# fred.
# colby.
# short-staffed
# conmen,
# apathetic,
# laya
# balem
# sung-ha)
# mill,
# mckenna’s
# oota,
# komatsu).
# military-grade
# (stanford)
# vignettes.
# (colin
# rayver
# scraw
# bernabo
# hospice,
# narrates,
# angrily.
# (chakravarthy)
# atley),
# typhoon.
# foree
# bellinger,
# leon;
# chaitra.
# mementos.
# gaz
# ting-kwong
# reanimation;
# world'.
# laps,
# exo-skeleton
# rae
# knockglen.
# gekkoukan
# stowaway,
# savyasachi,ahalya
# pepa
# does!
# people.[12]
# diamond,
# dees
# curwen,
# bison,
# assured.
# skins;
# william,
# leg.
# mukundan),
# relief.
# (sajjan)
# co-dependent
# partnered,
# hazari
# leafie's,
# lorraine)
# eyes),
# hordak
# giovanni.
# scientists'
# blind)
# oakmoor
# a-laws,
# pages)
# mctavish
# prieto.
# statues,
# acton
# geo.
# matilda
# requirements:
# (carter
# colombo.
# kinnu,
# ryota
# liana,
# meritt.
# ape,
# shourya)
# right-hand-man,
# ko
# ogallala
# law-breakers
# (jai),
# mechanade
# vatmeki,an
# did!)
# mallory's
# davut.
# ball.
# moga,
# lethal.
# seal,
# echolocator.
# glynis
# disappearing,
# aparna,
# flows.
# (jordi
# occasion).
# スカイ,
# ayodhya,
# denham)
# barfly,
# irby,
# aramaic.
# pavilion,
# trainor
# manson.
# self-denial.
# assertion,
# prophesied.
# blood-red
# ling-ching
# konatsian
# misconnecting
# above,
# (sela
# look-alikes
# sleepless,
# no-man's
# 92,
# (ulrich
# selim
# harmon
# chamerd,
# harris
# darkroom.
# misako.
# “co-operative
# carmen,
# हा
# pfister),
# shelly's
# gallo).
# 20,000
# ibelin,
# match;
# lines.
# jack-hammers
# unbreakable,
# fiesta.[1]
# veil.
# vampire),
# sully's
# storm-free
# blackmer)
# half-breed
# 6:
# kashyap
# playwright,
# romano
# financially;
# lock-up,
# shinnok's
# lcf-signed
# lyons
# craven.
# stiles.
# thrived,
# waller
# mid-to-late
# swanee's
# (darren
# swithins
# housework.
# kiswana,
# philosopher.
# bluteau),
# bernabo's
# roll!
# ramaiya,
# savalkar
# (dalip
# tailhook
# albrecht.
# minki.
# lavenders.
# arawak
# bolin),
# phrases,
# british.
# (restaurant)
# gilliam)
# naldi),
# grow.
# (seema).
# tomoko,
# bulldozer.
# toyama's
# dimpy
# bandy's
# (digger)
# paré),
# campeau's
# gasti)
# reuben,
# practitioner,
# strickland,
# uri
# (mason),
# escalating,
# rajesh,
# (wind
# marwari
# blind-sided
# pyunma's
# next”
# maine's
# /precious
# story.in
# (lupino)
# verlayne.
# (owen)
# groceries.
# (ooh,
# adversity,
# verónico
# clarissa,
# muldoon.
# madox's
# circumstance;
# boating.
# complies,
# (preeti
# boars.
# hatred,
# fostner
# enemies’
# hayter),
# elections.
# donohue,
# shaw)
# treasury.
# jedidiah
# cdc's
# abby's
# standoff.
# sixth-form
# businesses.
# affair—to
# elmyra
# seenathana
# newhartt's
# jockey,
# bulldog{wrestle]
# ‘disaster’
# spies,
# fleming
# films)
# hutt's
# businessman\seth
# vaithi
# jackhammer,
# osborne),
# bramford's
# uncommunicative,
# mayhew.
# rewards.
# westlakes
# 36th
# ashes.
# astronomy.
# snake-man,
# re-enters
# middair,
# ki,
# grady,
# (marianne
# roxy,
# cleopatra,
# dub).
# debris.
# evangelista)
# mukoda's
# wrecker,
# patterson)
# swings,
# that,sachin
# luchresi
# koufax
# snatch.
# berry)
# donan
# abramson.
# now-cool
# ex-hostages
# allardyce,
# lawless,
# protul
# moon:
# bin),
# aya's
# trash,
# mucho
# tepig,
# nicholl
# spasming
# pipits,
# sleat,
# jewels'
# 1940—but
# orfman
# subhankar
# hotel—the
# reality!,
# last,
# sounds,
# berry).
# drycoff
# barraud)
# abandoned.
# informants.
# walking?,
# monte.
# yanana.
# praise,
# plane?
# downes
# juni
# place.there
# double-parks
# slater,
# (clancy
# justify,
# har!.
# (variable
# bunty
# himori,
# esther
# pradip,
# valley;
# laroque
# flash-forward
# mathew),
# melanie,
# cordura.
# symbiote
# desu
# jagadish.
# reagent.
# moran
# sankar
# littlefoot's
# images,
# (harrison)
# 'kundavi'
# semi-trucks
# condominium,
# marriage,
# goodliffe).
# shame,
# brownstar,
# keno.
# worldwide.
# smarter,
# blocker,
# cairo,
# kazar
# olwen,
# se
# ashley,
# (disguised
# braces,
# saying—within
# firepower,
# d'angelo,
# hop),
# ramanujam's
# betty's
# poorly.
# joni
# wardell,
# hard-hitting
# bl&l's
# angie's,
# housekeepers.
# unfold.
# 'un-normal'.
# cliffhanger,
# riot.
# panther.
# hearth.
# cregger)
# maddison
# nail,
# uninvited,
# eilonwy,
# (kurt's
# hopke
# molyneaux,
# deer)
# ecstasies.
# gangnam.
# required),
# head?
# tommasso
# eli
# weird's
# go-go
# grue,
# branz
# gusts)
# deirdre.
# aimlessly.
# hippieish
# kyubey's
# sapphire.
# not;
# skylight.
# greedy.
# room)
# leverett
# (asin)
# bride;
# ordered,
# moksha,
# shopgirl.
# sanatorium,
# roychowdhury
# rajesh.
# dewey.
# lean,
# amusing.
# disgrace.[2]
# oogway's
# bangle.
# zebra,
# karthik(jai)
# landing,
# occupy,
# train-robber
# hubli
# thereof)
# gerrera
# (gwynne
# later).
# stranger;
# billiards.
# cajun
# minos,
# angeles–based
# reptilicus.
# (he
# yatterwan.
# chloë
# into'
# dallis'
# spica's
# round-the-clock
# skeet-shooting
# tancred
# finney).
# tao)
# engels
# rao);arrange
# erudites.
# kim)
# sweeney
# co-obsession
# ji-won)
# believes,
# buses.
# pallan
# (reni
# manorama
# substitute,
# khandilkar
# hart.
# piya's
# sharon's
# grank
# (ocd)
# videodrome's
# unwilling.
# arrangements.
# glinda's
# dentist-turned-bounty
# in?
# leelamma
# missing.[6][7][8][9][10]
# traitor.
# fiancée,
# unwell.
# coach.
# ritwik
# rurales,
# franciscus),
# planet.
# darren)
# (preetha
# corin
# montini.
# meanings,
# ranadheer
# enterprise-a
# black-clad
# tomonari,
# roronoa
# duma,
# preparations—town
# orientation,
# acquitted;
# suzuki)
# ultrasound.
# must.
# badly,
# bradman
# atheris,
# younger's
# cope,
# cruz,
# flack's,
# allow.
# cristina
# brigham,
# sctanley,
# pharmacologist.
# (santhanam)
# picot),
# vargo
# excessively,
# vairakannu
# employees.
# haysbert)
# at-risk
# els.
# jyotirindranath,
# subramani
# koster,
# yellow.
# prisoner-slaves.
# superspeedway.
# bordeaux,
# dash),
# called;
# geoff's
# brontosaurus,
# negligee.
# feces.
# whirl.
# fake)
# slam.
# (among
# periavar’s
# recaptured,
# (britt
# philip's
# andersonville
# out.[3]
# bala)
# barnabas
# snatched,
# shakthivel
# disoriented,
# friend;
# joanie.
# lapp,
# equikrom,
# cromarty.
# (sermin
# 1940s
# marko
# sloan)
# pennies),
# shefali's
# zachariah's
# kamala-
# crimes)
# starship.
# panchi
# catalina
# incline,
# (literally)
# ashi
# jacobs),
# o’shea
# threat.
# seaworld
# sabbir
# coaster.
# seraphia
# challenger,
# strikes;
# srivastava
# rpg
# atonement...his
# business.[3]
# unable,
# feather'
# goo-gaa,
# pattinson).
# arlette
# crude,
# cloakroom,
# consultation.
# x-ray.
# digbijay.
# phelan,
# (acp),
# moderation,
# fancies.
# reaper.
# e-type.
# biren’s
# farhan.
# stocks)
# paddle,
# arlene.
# hannassey's
# louis,
# subroto
# colorado,
# holiday,
# was).
# (instead
# dystopian,
# yip,
# stairways.
# (fairchild)
# bromley,
# rati
# flavor.
# ackerman
# pennington
# past—he
# anew.
# kevin).
# kravitzes
# manisha's
# (telford's)
# courageous.
# antara.
# nuremberg
# expired,
# xie
# postulants.
# zanti
# presses.
# quarreled.
# parijatham
# triad;
# t.b.
# coercion:
# silver?
# lift-off,
# rejimon
# simultaneously,
# used.
# japanese-styled
# brummel.
# hyderabad,
# tito)
# macoute,
# failure;
# descends,
# cyanoacrylate.
# (nakamura
# stooge.
# firefox
# 35th
# unreal.
# remembrance.
# tarnowski
# powder-8,
# (natsuko
# dreams,
# yee.
# (jithan
# actually.
# alana's
# hulbert),
# self-destruction,
# two:
# gillray
# pour.
# stavrakis)
# force’s
# conspirator.
# civic-tv,
# (daria
# gyanmarg
# frazer,
# rows,
# cowboy.[1]
# step-mom's
# adventure.)
# hartman.
# eliot
# haunt,
# eyebrows),
# shantanu.
# misa
# aladdin
# gossett,
# craig)
# englewood,
# gk.
# kailash's
# haye),
# holds.
# sample.
# hearn,
# books.
# englishwoman,
# daay
# (hinde)
# madhumita.
# 20-minute
# arctic.
# codeine-laced
# nickleby
# parameshwaran
# coward,
# predators.
# mahjong.
# quaint,
# field)
# marquette),
# from?
# shifts.
# adams)
# break-in,
# (anee
# task:
# haldiraam
# brownstar
# george
# ambika
# taruho,
# mirza,
# sandesh),
# kaif).
# 'singamalai'.
# bobbikins.
# unthreatened
# larry's
# girlfriend/model
# sailor,
# giggles,
# ikuma's
# graboid
# remain.
# shahani
# toilet.
# humphries'
# kents,
# friends'.
# nomi
# karuppu
# alam
# (kaberi
# berlin.
# pickpockets.
# borobudur
# fandorin
# maccleary's
# jig.
# julian's
# burials.
# connors)
# empires.
# concurred,
# levi,
# highway.
# asifbhai
# (isn't
# ballad;
# drone,
# brati,
# beforehand.
# prank,
# (kendall
# re-paint
# wagh)
# bulger,
# levon
# total.
# shankar)
# landy,
# shenandoah,
# blasted,
# trouble,
# file...
# porky)
# harbottle),
# kingby.
# azerbaijan,
# general’s
# fudd-like
# saloons,
# larsen)
# £1,400
# tours.
# domestication.
# zardoz's
# lynn.
# man-beasts,
# freeman,
# shortages.
# malinger),
# derya
# arabella’s
# afar,
# fighter!
# essex,
# injun.
# asher's
# olivier)
# (gautham
# attention:
# namaaz
# wynan's
# corporeal,
# juliet
# middleton
# devouted
# going,
# (drax
# dano),
# cady
# popday
# (gateson)
# zisi
# marty—come
# jonas.
# nance,
# kennedy.
# mcgrath)
# englund
# romanoff.
# cobretti,
# takada
# chai.
# li.
# toshio.
# (razzak
# riggs),
# knowles).
# caviezel)
# (sydney)
# tek
# mano’s
# 'the
# quincy
# witch-hunter
# chan,
# 10–6,
# devadasu's
# germans
# çanakkale,
# pack.
# (ada-nicole
# treadmore
# betz),
# diner/tavern
# have.
# biswas,
# drovers.
# glenister)
# held.
# secrecy,
# romero),
# co-wife
# singh),
# duffy
# carson's
# holt,
# displeased,
# scandalous;
# mcquade’s
# “one
# (franken),
# rocco's
# jurassic
# garrucci
# nirvana,
# gopal's
# machine.
# foundress
# dippy.
# ramine's
# taxi-driver
# dutty
# hada's
# frenatore
# wansey),
# intensify,
# hatchett,
# gift:
# (enchong
# jurisdictions.
# (dirk
# burdett's
# damaged,
# summers,
# daisy.
# bunglow's
# sutton's
# jiang.
# founders'
# 28-year
# ghetu.
# vaikunta
# orrie
# omalu
# gerta
# enthusiasm.
# argenziano).
# re-programmed
# viewers.
# becky;
# added,
# matron,
# d'souza),
# kodai
# crowford
# macneill),
# (teresa
# winslett-richardson,
# (mai
# other!
# lorraine's
# conception,
# cards![1][3]
# subrahmanyam's
# balraj
# stanhope,
# commotion,
# (reena
# whalan
# photo.
# uchiyama's
# mall,
# garden)
# donald;
# coffin-maker
# tell-all
# trains.[2]
# two-story
# surrounded.
# brimley),
# tedium-filled
# tails.
# right?,
# giorgio
# okinawan
# baby-duty.
# loud-mouth
# gandaharians
# jacket,
# sheridan.
# (rodrigo
# blood-laced
# (denzil
# advertising.
# taguchi/christophe
# yamaguchi)
# collins).
# tojo
# bittle.
# niigata
# masses,
# baby).
# silence;
# castanets,
# (controlled
# (camera
# arrival,
# leffingwell
# bird!
# sexuality.
# flourish.
# abijot
# dipu
# baqar
# throwers,
# stigmatised
# geronimo.
# lustig)
# (ana
# trisha.
# (fields)
# angad
# doppelgaenger,
# (orlando
# (m.k.
# shaddin'
# georgie
# knifepoint
# poorer,
# tithi,
# walia)
# neighbors!
# bonda
# ambrosia,
# food.[4]
# mortician,
# profit-making
# andrews;
# motorcycles.
# thunderbolt,
# sulfide)
# gilford),
# joe
# broadcasts,
# sivaraman
# three-point
# manis
# machin
# f-16c
# sofaer),
# appeares
# (misako
# robins.
# mochida,
# kile
# slopes.
# (approx
# br.
# thoughts!
# n),
# arushi
# rita's
# tortures,
# team-building
# (gilda
# arrogant,
# minnal
# scott’s
# webber
# experimentation,
# shinichi
# rakka's
# 2000,
# turag
# emerald-encrusted
# constantine.
# jimeoin's
# (prudence
# stalls.
# chrystall),
# haven,
# hagan
# ex-cons
# after-party
# most,
# aragorn
# customs:
# bruton),
# janice's
# astrid,
# (nandini
# colt.
# safiyumma
# illeana,
# deathbed,
# “eh
# hester.
# lewis's
# hello?
# trio-trip
# leona
# petroff's
# howls,
# dimetrodon
# begin,
# (conducted
# johannesburg
# kenny)
# click.
# pere
# soon-yi
# (manojit),
# worsens,
# nux,
# yeah,
# kusano).
# chun-yi,
# ishwaram
# (vital
# maire
# hilbert
# brudah
# alive'.
# oldring,
# gorshin)
# maximilian's
# bret,
# namtut
# younger[clarification
# nagarajah),
# forest.[7]
# makes.
# roundup.
# headline,
# hing,
# meditations,
# awl.
# chutki
# silver-smith),
# kirina.
# (bruno
# giri
# selina
# wike
# hold-up
# responsibility.
# 1900:
# macclaggans.
# douzi
# hridaymardyam
# by-election.
# opinions.
# (tim
# jeffy
# 3m.
# pet,
# sarcoma,
# 250,000
# twitter,
# hi-lo,
# ever.
# (moya
# (now,
# or--
# joy.
# anaesthesic
# cheung)
# in).
# ragini).
# pursuit,
# neweyes
# kyung-chul
# jockey.
# patch-up
# macross'
# gayby—about
# raghuvir
# philippa
# fenyang
# waggett
# wound.
# madonna's
# olympics,
# new-born
# (biehn)
# neagle
# grayson).[6]
# mongolia,
# sue's
# jamnadas,
# suzuki's
# crag,
# parkers,
# potter-shine’s
# out-of-the-way
# necktie.
# kimbough
# fountains,working
# sackhoff).
# connie.
# announcing,
# g-forces
# lordsburg,
# belu,
# elsie,
# impenetrable,
# deeanna
# uaw,
# katamarayudu's
# kirby's
# remarks.
# goon-nam
# bern
# (jimmi
# pregnancy)
# texter),
# quinn),
# ndofa,
# (zissis).
# trampled,
# millionaire.
# neville.
# hk100,000
# wallis).
# andallu(mumaith
# phone)
# pancakes),
# finkleman
# kapadia)
# blue-gray
# haripat
# bergin,
# 400-car
# kadapa-based
# skylab
# horn:
# feels.
# connor),
# world-weary
# mitzvah,
# scorned,[1]
# outtakes.
# wilmer
# vijay
# carlotta's
# filipino-american
# possession)
# michaels'
# cranmer)
# hall);
# miracle.
# karle
# sampat
# 'die.'
# cromwell,
# abellana)
# example.
# gargoyle.
# charvet's
# grubb)
# walz
# diarrhea.
# lassiter,
# reagan
# goodall),
# rokon,
# devries
# (venkat)
# maya’s
# drake,
# often.
# bansi,
# insectopia,
# given,
# retaliation,
# দত্তের
# divorce.
# times:
# school—an
# kalidasa
# minoton
# wattis).
# naraka,
# dorker's
# outlaws—one
# headstone,
# overtaken,
# smoove)
# (kushboo)
# wooing,
# everyone’s
# re-ignite
# completed.
# reptile.[2]
# convict-transportation
# (klugman).
# kanako
# blood-loss.
# painters,
# jiazhen
# pirates'
# sarkar
# davidman
# vandana.
# librarians,
# kunzru),
# attempt;
# trick:
# wilhelmina
# machado
# orangutan.
# servant.
# pariahs,
# horn;
# rivers),
# ...
# bacteriology.
# rho).
# kirby,
# valentine),
# vaccine,
# (rampling)
# d'afrique
# megan.
# kimie
# tomanski
# gamal
# ramdayal
# flick,
# (teruo
# brett)
# kaprov,
# pochi
# fuk-loi,
# deleted,
# red-headed
# chu
# (accompanied
# naughton).
# reborn,
# lamba),
# montiel).
# pc
# mariella
# offer;
# chameleons.
# lorre).
# fashion.
# daystar,
# brahma,
# notion:
# 'body'
# black;
# rajkumar's
# skiing,
# ex-policeman,
# castillos
# maitre
# (de
# miran
# velu,
# non-magical
# methamphetamine.
# killian,
# twenty-two
# rajarshi
# reverse,
# bracketts.
# macbeth's
# ward);
# billing,
# chellapandian
# karlovy
# capitalise
# sreenidhi,
# diya
# locale)
# idhayakani
# ockmann
# beforehand,
# defector.
# chandavarkar),
# emre's
# shaw;
# feliz
# ox-cart.
# (brooklyn's
# gangster,
# spoon.
# kanon
# kokumo
# struggles.
# rorschach
# zaror,
# (kallu
# 79th
# commercial;
# ayaan.
# kitty)
# jenna
# plot.)
# malliswari.
# ex-soldiers
# nanomachine
# mother-in-law-to-be
# wagner's
# drunkard.
# diff'rent
# chandu
# format,
# writer.
# naranga.[1]
# dan
# nerves,
# flax,
# hima.
# vijayakumar
# barve)
# durfee)
# (keanu
# lue,
# intrigues.
# pendlebury
# corcoran's
# syncs,
# (maki
# kaito
# meeta
# raton
# daughter’s
# employ.
# costs),
# putman's
# francs,
# (nobuko
# routh.
# quacking.
# sherry,
# (cheating).
# conan
# tratner
# balan),
# oven,
# train.
# was.
# esra,
# 'steady
# mais)
# ​1⁄3,
# 'harlot'
# stricks
# sr,
# double-cross,
# mechanic)
# pastell).
# lakhipur
# us.
# harriet,
# briggs'
# elmer.
# unrecognizable.
# mcinnes)
# shajahan)
# patents.
# rochester.
# storybook:
# brophy
# neurotoxin
# retort.
# strippers,
# ahab,
# durrant
# ornaments,
# testu
# gaspar
# videotapes,
# neeson),
# pinkerton,
# xiaolan's
# toretto,
# fletchers'
# examined,
# volunteers,
# (upendra)
# movie.disheartened
# muthappa.
# territory;
# (brother)
# parting),
# orville
# generosity.
# mara)
# chao-tsing
# castle.
# bhai,
# first-time
# stardom,
# code-named
# unenthusiastically)
# disdained,
# pregnancy;
# bio-chemical
# moreno.
# venjaramoodu),
# dhawan),
# choices:
# smiling!)
# jonas's
# kishenlal.
# rachael
# air-drumming
# clum,
# stephens'
# east-bound
# stool.
# everyone's,
# det.
# isham
# finistirre,
# protocols.
# (karthika
# tompkins)
# left),
# amanda's
# (mandarin
# royce'
# (muthumani),his
# azmi),
# years.
# hopkins.
# mata
# aruna's
# shaleen
# congolia
# rape.
# to,
# kraków
# c24
# lay.
# costume)
# already)
# riot,
# symphony).
# dinello)
# ashwin,
# okay.
# bender)
# kondaveedu
# charades.
# then-teenaged
# provisions,
# dqed
# disappearances.
# photographing.
# omer.
# problematic,
# bozworth
# francisco
# arlis,
# sudha
# dody
# aruvaal-making
# bierce
# appraisal.
# gates...
# kuljeet.
# helvenshaw
# roshan,
# wilmington.
# papy
# woman.
# voice-recognition
# shama,
# 2017-08-28.
# astaroth
# vindictive,
# backside.
# quarterback,
# moina's
# ruse:
# 'tank'
# terragarossa,
# cyanoacrylate
# pozzi
# poitier)
# own.
# fairytale-hating
# (vacrf),
# baptism.
# zombie’s
# dalia.
# sanjana,
# waves,
# silchar.
# immaturity,
# murney's
# animalistic.
# nicholas's
# sathyam's
# bodo,
# manwaring
# seban's
# zamir
# fishburne)
# cheetwood)
# housecat,
# atom.
# crown).
# shapiro,
# (nithiin)
# body-masked
# 'discover'
# branson)
# airbornes
# £5,000.
# half-pint
# ex-fiancé,
# russ
# one’s
# collins's
# below-ground
# hard-heartedness
# embarrassment.
# sharda's
# firefight,
# stake-out
# achieved,
# velvet?
# brandt.
# cates's
# shiomi),
# tom;
# flynn,
# lopez's
# timothy,
# sari)
# catalyst.
# emphasizes,
# drug-dealer
# (krish
# (thilakan)
# evangeline,
# fay.
# carriers,
# sucker-punched
# oklahoma.
# mother-in-law
# o'mara),
# torpedoes.
# taupe,
# (trader
# booklet.
# kurt's
# dyna
# generally,
# makato
# (bronson)
# steenburgen),
# (hartnell)
# beijing—not
# polish,
# siu-fai),
# orhan,
# laubardemont.
# williams)
# self-disgust,
# holland
# knightley)
# subordinates.
# luz
# promising,
# sheshadri).
# counselor.
# sinatra's
# gemini
# (mao
# apart,
# puncture,
# gyllenhaal)
# (despite
# lidia
# talent,
# angus),
# summarised
# conservative.
# bribery.
# unfinished.
# spanagers'
# v8
# tease.
# core,
# sweetner
# arrive,
# esseker.
# hachita
# hoping,
# chanda).
# lawful.
# struggles,
# (sailor
# (tegan
# hada,
# harriman's
# 'planet
# pyro's
# ozu,
# bottom;
# (mel
# void,
# solidarity.
# smallville
# gam)
# tom-tom
# stage-hand
# follow-up
# ledbetter,
# (pelka),
# penthe.
# murton's
# derailment.
# aden
# diary,
# bovard
# victories.
# rui's
# turmoil?
# hit-men
# jailhouse.
# brookview
# psychomanteum
# arabella.
# oates),
# dacascos)
# karuppayi
# levene's
# veeriayan
# begin;
# minuscule,
# biswas),
# sympathetic.
# (910
# mei.
# myself.
# kyubey,
# roadhouse,
# six-shooter's
# mugshot.
# girl's(earlier
# futuretech
# mo's
# (ganesh
# ajay's
# haname
# charudatta
# rennie
# kleve's
# pitka
# mussel.
# hyperfold
# tommie
# shakespeare’s
# hope.
# peckham
# curran's
# skepticisms.
# (mann),
# illegitimate,
# intact.
# thea,
# brazil's
# engineer.but
# murder;
# barricade,
# presiding.
# mentally-disturbed
# .45s
# suri.
# (menashe
# (parkes
# conforto
# funerals.
# tv's
# (kathal
# rushi’s
# oates)
# bitter,
# gophers,
# shortly.
# dench's
# p.j.,
# mapache's
# modibo,
# idrish,
# spoil—lethal
# ridges).
# prine),
# black-and-blue
# madoushi's
# kaleb,
# nevin
# fisheries.
# (lothaire
# 1950s-styled
# gavin,
# rocco
# innkeeper,
# now-suspicious
# rhodes)
# (margaret
# amish-like
# handleman
# edmond)
# shut.
# gage;
# knowledge'.
# o'hara,
# 200-foot
# chim
# mid-level
# dissatisfaction,
# trautman,
# meremma
# troubles.
# salem
# b.a,
# juliana's
# sibylla,
# 30's
# sheriff’s
# chula
# spengler.
# l.t.
# outward,
# steamroller.
# ithihasini
# chaan
# lo),
# visa.
# saturn),
# kilvaine
# emile.
# jeevan,
# bachelorhood,
# howie,
# (fiona
# season,
# demon)[5]
# dunbar,
# witcher)
# tonkin),
# (hassan),
# bale,
# fired,
# e.n.d.
# william's
# loring
# (corporal
# soviet,
# luther)
# water-skiing,
# (aari)
# azizah,
# swimmer,
# predicts,
# automobile.
# frequents.
# revnell
# fun-loving
# renault.
# announcer.
# ducky,
# sravani,
# writer]
# drazen)
# commences.
# (actor
# name:
# diego-suarez
# sachie.
# darrell's
# sylvester,
# armenian
# sissy.
# marisa
# kulbhata
# souls,
# (gardner).
# cady.
# stiles,
# attachment,
# farms,
# kaneda,
# tranquility.
# (santu
# hikawa
# astonishment,
# failed.
# stanton.
# arius'
# montage)
# michael-meagher
# jackpot.
# anterograde
# satyabhama's
# begin...
# s-33's
# irony.
# zoanoids
# long-eared
# 1699,
# abiocor
# reprogrammed,
# tanis.
# maureen
# vandalism,
# marksmanship,
# vasudev
# yaz
# shion.
# naked.
# doan
# dore),
# corrigan.
# forge,
# westernization.[7]
# abijith
# vinitha
# fright.
# ikari
# smilodon.
# life-prolonging
# durgadevi
# (nakul)
# axis-occupied
# stander,
# recuperate,
# fredda
# reanimate,
# chester.
# backdraft,
# spoon,
# suze's
# zi's
# boleyn,
# beavis
# volleyball,
# andré
# nisha's
# sukran
# levy),
# cissies
# coveted,
# conlon/jones
# gnn,
# oahu,
# 'person',
# dawe)
# faiz
# sedley,
# shaolin
# (yau-gene
# sympathizers,
# ewing).
# zapata
# acrophobia.
# felina,
# girl-next-door,
# (すきま,
# widmark).
# x-men
# honor;
# head-hunting
# petrie).
# happyly
# mountain-isolated
# 'aluf'
# (rajnikanth).
# diem,
# city.
# code;
# creatures,
# angeles)
# furness),
# abrams'
# alcohol)
# castellanos)—come
# collins),
# ericone
# ketcham.
# carlitos
# grudge.
# puri)
# towed,
# ab
# (derick
# ground.
# knox)
# fanfan)
# seema;
# whining.
# winning;[2]
# beldam,
# lazlo.)
# .but
# arm’s
# gunfights,
# favreau).
# sachein
# galt,
# shipments.
# shopgirl
# tattoos.
# lawson;
# (administered
# rajskub)
# lakshmi,who
# surtayne
# charizard,
# hollis
# cat-lady
# k-2so
# flights.
# carrey),
# released.
# drafted.
# (presaged
# dorthea,
# ketchum
# powers'
# beard.
# hancock),
# phoebus
# perpetuity.
# plotnick)
# strokes.
# hunterwali,
# human-vampire
# prithvi,
# seung-ho's
# whore),
# seoul,
# derezzing
# frustrations,
# commiserate,
# karnataka
# technique).
# kusum.
# mesmerised
# (mamiko
# moody,
# knock-off
# (poonam)
# mail-ordered
# stamp.
# ex-love
# babe.
# marino.
# shanmugavel's
# starburst
# tenneray's
# sightless,
# alzheimer's
# (juliette
# reintegrated.
# duvalier,
# acapulco
# rolly
# bhishma
# gareth
# kanakayya
# yoshiyuki)
# autism.
# shivanand).
# clubbing,
# jack-o'-lantern
# undaunted,
# sumathy
# (fairbanks),
# irises-out.
# beck)
# kadhir,
# mayley
# 9.00,
# oneida
# t.j.
# brockton—a
# money-raiser,
# misidentification.
# adrienne,
# tayloe
# incoherently,
# joyce
# executed.
# true.
# drifters,
# reunited),
# conflict,
# mcing,
# prometheus
# ramp;
# commonplace.
# carnivore.
# stop;
# slobokian
# rafi,
# shaun's
# stroup).
# tiana.
# car-mechanic.
# longden,
# coming:
# genovia,
# coworker.
# (lindsey
# wistfully)
# queensland,
# disastrous.
# reddy).
# journalist.[1]
# outbreak,
# stanhopes
# feather;
# gurgling;
# institutionalised,
# shiina),
# moffet
# waggoman
# abstinence,
# rose-bedecked
# carmela,
# mykonos.
# satterfield)
# naresh)
# adolescent,
# deserter.
# explosions,
# sea-bed.
# removed.
# samanta
# afloat,
# terrific!,
# seller.
# mother.[3]
# nemec)
# sammi's
# nahum's
# raja?
# aylmer)
# blood).
# barbarosa!
# on-stage
# puja.
# basketball,
# castrated.
# 1881,
# feinstadt
# jennifer.
# sanskrit
# chawla).
# callahan
# huh!
# nanda's
# unite![6][7]).
# m.l.a
# marais,
# rishi.
# sidekick,
# lafe
# greco.
# sohan
# aishwarya
# srivastava's
# obelisk,
# barry.
# kin:
# quinney
# martin,
# deepika(tanu
# agry
# yehia.
# laemle
# henchmen.
# (race
# mummy,
# racine.
# camel-led
# agnihotri).
# willes),
# self-described
# azusa
# saffra
# royapuram
# (rima
# reenter.
# thulasi
# parent’s
# nandhini's
# bert
# rana.
# detonated;
# joshua’s
# vinayak
# mini-sub's
# projectionist,
# $6
# laut
# cavalli)
# station/junkyard
# spartan,
# keung
# deputy,
# down!
# choi-lam
# (kurupt)
# lui
# substitute.
# shirt,
# heathercrest
# toughness,
# ottilie
# origins.
# krüger)
# moments.[1]
# son,
# tara
# serial-psycho
# australia,
# sandinista
# morales—who
# matthew,
# thora,
# jin's
# watching;
# minnie,
# asuna
# coffee—dunkaccino
# wildhack
# paz's
# codee),
# ernest,
# (tchéky
# homans),
# wife.[3][4]
# tobio,
# approach,
# narrators:
# morgan.
# pheromones,
# bening).
# fudd?
# forever?
# tiranga.
# bar.
# klimenko
# (munro),
# tanonaka)
# benwick
# ardeth's
# kates
# bar,
# hooks.
# sabitri's
# treasurer,
# 3,000th
# life!
# nainital-based,
# lever,
# size),
# meenakshi,
# year—and
# blackjack.
# tate's
# adarsh
# payload,
# lingeries.
# departments—and
# war.[4]
# takuma
# diggs),
# trial,
# learoyd
# brennan),
# paganino's
# ryckman,
# malabar,
# shadows,
# drona's
# now-robotic
# headman,
# ebenezer
# witches—the
# maltese's
# voice-over:
# richmond
# kuzan,
# huge,
# goon.
# forcible,
# soon-to-be-executed
# right!
# bertie
# fridge,
# alphabet.
# smithing
# gaja
# fancy)
# christian).
# twigg
# omar).
# electra)
# thorne,
# srikanth.
# remained.
# torment.
# explaining,
# meg’s
# roenick
# paro
# area)
# tom.
# rightful,
# official.
# keshav.
# profiler,
# saraswati,
# motor.
# barrows,
# (raeden
# show.[3]
# son.
# 'hee-haw',
# 1844,
# laxmi).
# deliberately;
# commit.
# percival',
# crosby.
# judith.
# (ari
# initially.
# vickie's
# mckinnon,
# langham
# karras's
# sever's
# ramirez,
# grotto.
# (meinhart
# hwi-do
# kingship.
# kraven's
# dinner,
# 25-year
# poet,
# appa
# (tala
# insanoflex,
# butter.
# arrives—and
# ugrappa.
# conviction.
# cutlass.
# paulsin).
# cliffside.
# singh).
# miko
# magnanimity,
# boarded.
# jessica’s
# hossain)
# gloomy,
# squidward
# byaki-buki
# reprieve).
# birkell),
# (hedy
# unnikrishnan,
# black—in
# marylin,
# mercenary.
# kalima,
# marji.
# fulton’s
# dearly.
# de-age
# marlon
# gallagher's
# shiv-sagar
# sorrows.
# carroll
# peppers,
# (mushtaq
# (carlson),
# babuji
# smell,
# polk
# bercovici)
# arms.[3][4]
# innocence,
# harbour
# longings.
# muckety-mucks,
# (lainie
# aviv
# bridgeport
# vikranth)
# frontman
# (victoria
# co-worker
# spotlight,
# (l.o.o.k.e.r.)
# biggs).
# walia,
# kalyan,
# l.i.c.
# dakshinagiri
# plummeted,
# (solomon)
# binges,
# defect,
# medjai.
# tariffs,
# kingpin,
# assailant.
# reptile(under
# waterboarding.
# sugar,
# boil,
# brusqueness.
# test.
# produced.
# babette.
# $20,
# sunita)
# pleas,
# alina
# kamina.
# mall).
# flashback.
# christella
# programming.
# tung,
# sportsmanship.
# sachidanand)
# bagrov
# sahni),
# (slim
# (chief
# out-dance
# removed;
# shankar),
# dog!
# daystar's
# indrajit,
# greenbow,
# dumbo).
# (poulton),
# megumi's
# crale
# wing),
# authority,
# cosmonaut.
# maillane.
# vattathil
# mysterious,
# bellerophon.
# dench,
# mătăsăreanu,
# tahoe.
# karthis
# feels,
# alldredge)
# (translated
# arena:
# killed.[note
# results.[2]
# shimazaki
# womanising
# raza
# (carlisle),
# chatterjee)
# kinderman,
# strauss)
# nubian
# activates.
# anwar.
# fast-running
# homesteader.
# beacon,
# lucero's
# chan's.
# pansy,
# self-control)
# korda
# contenders,
# red-faced
# petzik
# magnus
# naam….preethi
# janey,
# conan:
# export,
# chopra).
# ketcham's
# d'angelo),
# elias
# yamanaka
# troggs'
# bouldeston
# alcira,
# beales
# (elanne
# d'artagnan's
# felipe
# bhanwar
# futile,
# mabel
# exploded,
# (huff),
# acorn,
# ghinua
# barbi
# cardell
# pallette),
# karly,
# wynn),
# $9,800,
# kadapa
# $700,
# pranabendu,
# pecos.
# hongwei).
# (yahoo
# approaches;
# shaffir
# carvalho
# guinevere.
# rebuys
# sona
# procedure,
# mockery.
# jakarta
# albert's
# (pepe
# rodeo.
# goodbyes,
# alper
# (worth),
# jobless.
# haruhi,
# brownlow,[2]
# tunner
# step-siblings,
# telephone.
# onward,
# story-
# adderall.
# dayan)
# bela's
# ephors,
# (resembling
# stomach’
# (milton
# possibilities.
# skimmer.
# morph
# lorena
# leeches'
# 'school-teacher
# role),
# bettger)
# o'dea.
# ritchie,
# gita,
# burris
# gato,
# teng,
# alexa,
# aruna
# valmont's
# sailor.
# alfred.
# losses,
# nakaoka.
# paderewski
# breach.
# breeding.
# hassler's
# mugger.
# bang.
# prosecution-witness
# nayok'
# elva,
# klebe)
# (morton
# jua,
# inheritance,
# cottle),
# billibud,
# up:
# deborah's
# stan),
# chevalier.
# retreated,
# dheeraj.
# novak,
# life.'
# all-boy
# claims).
# husband.[2][3]
# wedding.
# wilke)
# empty-headed
# home,she
# dehra
# blossom,
# panhellenic
# condition,
# nayaki
# beatrice,
# b.e.t.
# satoshi's
# assistant.
# bookshop.
# culprit;
# meeker.
# bachelor,
# skin.
# mustafa,
# sada)
# co-operate
# six.
# rasmusson
# pills)
# tuesday,
# nunchaku.
# bikini-clad
# lópez
# celia
# clique.
# cennet,
# purview.
# transference,
# mansapota.
# danova
# kluger,
# buckley),
# gotti.
# callistratus's
# tattooed,
# ferriman
# partner;
# teth,
# rudely,
# (marcel
# tift,
# horatio,
# reactor,
# neeta;
# gutted.
# realize,
# berkoff),
# leena,
# venable
# holliman)
# rediscoveres
# warren.
# childlike,
# mobston
# cherokee,
# cass,
# heat-sealing
# poornima
# parera's
# feds'
# partially-wrecked,
# tang)
# watch;
# weavile
# looking-glass
# nerv's
# ex-con,
# manhattanite
# goutam
# sponsitility
# vaccination,
# lemke
# streak;
# yuen-sing.
# home-ec
# matty.
# jarol
# $6,000
# saleha),
# gaumont
# taxi-driving
# stations.
# tatum),
# strannix's
# choran
# tzipporah.
# dreamfasting,
# for?
# pig-keeper
# mikako
# prize,
# gupta's
# mikhi
# thillanayagam
# safes,
# mirror—three
# explodes,
# hijacks.
# masseuse,
# webber's
# oswald
# screweyes.
# woods;
# riley,
# kimbough.
# “bad
# name-tag
# philippe
# work).
# peloquin
# endeavouring
# avi.
# eko
# kallulik,
# dongming,
# criswell.
# perspective.
# coconut.
# stocker
# thayer)
# bradford)
# seven-month
# rejects,
# wargames).
# leaf.
# gigolo,
# (saleem
# narsimha
# zimmer.
# ames,
# kogan
# sweetheart,
# vcr's
# wifehood),
# bounces,
# (bokeem
# return.[2][3]
# i-401's
# management.
# incinerator.
# bowgate
# adventure,
# ambassador)
# nap,
# pathak),
# udf.
# lakeview
# cannon,
# ranvir.
# ruhk.
# $90,000,
# sue.
# non-mormon
# turner),
# overturned.
# rk
# then-girlfriend,
# superficial,
# dignam).
# elias,
# gr76.
# indrajit
# cantina,
# wiĺth
# j&m
# zombies—believes
# isaacs
# brakes.
# quade
# sulekha
# (jeannette
# phoenix,
# boovs
# reciprocates.
# coxes'
# jaeger,
# (monte
# maki),
# entertainer,
# swope
# hilary
# montu
# sweethearts,
# blessing;
# kulkarni)
# solly's
# chicks,
# magid
# convenience.
# mess!
# herschel
# bellows)
# romancing,
# (banerjee)
# (nagineedu).
# jamil
# —becomes
# britai
# ganymede.
# hydronium
# 1897,
# ganges
# vere
# denver,
# satanic.
# macpherson
# real-world
# derval),
# detective,
# bilal's
# md
# oakton
# co-actors,
# marvels,
# make,
# a.k.a.
# firm)
# superstars.
# signs,
# (volume
# hanner
# bhinder,
# heiderich,
# weeks.
# asuka's
# debu.
# eternity.
# dumbo's
# flint.
# lebron,
# sheen),
# akshay.
# poses.
# wilder)
# kagami
# wolfit),
# bartleby,
# aspect,
# duet,
# chinna.
# smee
# bukovina,
# boyar),
# traditional,
# flagship.
# reptilicus's
# convex,
# firepower.
# billingsley).
# crew—including
# snowboard,
# apocalypse.[1]
# exonerated.
# clayton
# gulag.
# bryant.
# one-third
# como,
# humour
# colds,
# vanie
# qissi),
# govindan,
# “them”
# indraneil
# soma's
# heles.
# mayu
# yeung.
# answered.
# close)
# mak-zi
# resonates,
# annex,
# (cecily
# tormentors.
# guises,
# dropped,
# sanam,
# rebuffed,
# someyer
# kent)
# dupree
# toscani,
# stetz
# drave,
# wale,
# (seban)
# nandi,
# camaro.
# 'chub'
# angiulo
# selfishness,
# mckean)
# dreamings
# squandered,
# chandragiri
# mirage,
# demetrios,
# 1745,
# profession.
# cats.
# customers:
# self-contained
# persecution,
# cheol-soo
# wonderful.
# sundar
# watson's
# velociraptors.
# greece,
# pheasants,
# yip.
# crew-mates
# fawcett).
# everything.
# mavani).
# proportion,
# (peepo),
# other;
# implants)
# matasri
# aida)
# akinnagbe),
# hunt),
# scientist)
# babbit
# (ginger
# cavatica,
# hold.
# slim.
# sabah
# great-great-grandfather
# whitaker),
# arno,
# hickock,
# bobbie's
# anglers'
# elspeth,
# may,
# nung's
# sergio
# brewster)
# detha,
# firsthand.
# depth,
# gritty,
# seen,
# viki
# business),
# machete-shaped
# stony-faced
# (monkeys)
# dream-recording
# sreelekha
# general--now
# fishermen,
# crash)
# estrangement,
# respall)
# shaitaan
# (travolta),
# raynor's
# sheehan
# kurt.
# rectified,
# jungle,
# $6,132
# suma's
# sickroom.
# sdf-3
# canaan,
# goone
# mom,
# tran's
# transfusion,
# pup).
# re-investigate
# (asit
# nickie,
# elvis-type
# arles
# gunpowder-rigged
# sivaji,
# battalion,
# murkworks,
# ashima
# wringle,
# edmonton
# mother)about
# milieu,
# (shrikar
# backroom,
# stalked,
# nicholas
# dinnertime,
# freedom:
# philosophy:
# average,
# morality.
# warriors)
# (yelena
# feldstein).
# beat-down
# (ali),
# cliffs.
# off,as
# (venniradai
# (dandapandi).
# (quinn),
# bhattal),
# cherian.
# policeman’s
# holdouts,
# (ghosts,
# d'honneur,
# godfrey,
# etra,
# desires.
# 20,023
# o'regan)
# mcclaury,
# conservative,
# bousche,
# reappear.
# shaman,
# ulysses
# detail.[2]
# ak,
# hansal
# victors,
# kharbanda).
# coen.[7]
# unreciprocated
# directors,
# chinki,
# forested,
# selected,
# debunker,
# grunty
# mann),
# meeks
# sturdevant
# for—this
# documentary.
# lush,
# an-2
# chaser),
# gout-bound
# apprehended)
# bayou,
# cavalryman,
# cooperative.
# nets,
# erxi
# 1883,
# alchemy.
# nicola.
# isabelle.
# mcready's
# crash),
# (cary-hiroyuki
# duggan)
# chevasse's
# mother-in-law,
# fgm
# hiroko,

# %% [markdown]
# ## Pre Processamento

# %%
# Function to standardize dates
def standardize_dates(text):
    def _month_to_number(month_name):
        try:
            return datetime.strptime(month_name, "%b").month  # Abbreviated month names (e.g., "Feb")
        except ValueError:
            try:
                return datetime.strptime(month_name, "%B").month  # Full month names (e.g., "February")
            except ValueError:
                return None  # Return None for invalid month names

    def _handle_two_digit_year(year):
        if not year:  # If year is None or empty
            return ""
        year = int(year)
        return year + 2000 if year < 100 else year

    # Date normalization using regex
    text = re.sub(
        r'(\b[A-Za-z]+) (\d{1,2})(?:st|nd|rd|th)?(?:,)? (\d{4})?',
        lambda match: (
            f"{int(match.group(2)):02d}/{_month_to_number(match.group(1)):02d}/{match.group(3)}"
            if _month_to_number(match.group(1)) is not None and match.group(3)  # Ensure month and year exist
            else f"{int(match.group(2)):02d}/{_month_to_number(match.group(1)):02d}"
            if _month_to_number(match.group(1)) is not None  # Ensure month exists
            else match.group(0)  # Return original text if invalid month
        ),
        text
    )

    # Handle formats like "8-Feb-2013"
    text = re.sub(
        r'(\d{1,2})(?:st|nd|rd|th)?[-/.](\b[A-Za-z]+)\b[-/.]?(\d{2,4})?',
        lambda match: (
            f"{int(match.group(1)):02d}/{_month_to_number(match.group(2)):02d}/{_handle_two_digit_year(match.group(3))}"
            if _month_to_number(match.group(2)) is not None and match.group(3)  # Ensure month and year exist
            else f"{int(match.group(1)):02d}/{_month_to_number(match.group(2)):02d}"
            if _month_to_number(match.group(2)) is not None  # Ensure month exists
            else match.group(0)  # Return original text if invalid month
        ),
        text
    )

    return text

# %%
# lowercasing
def lowercase_text(text):
    return text.lower()

# %%
nlp = spacy.load("en_core_web_sm")

def lemmatize_text(text):
    # Process the text with spaCy
    doc = nlp(text)
    # Extract and return lemmatized words
    lemmatized_words = [token.lemma_ for token in doc]
    return " ".join(lemmatized_words)

# %%
# stop words
stop_words = set(stopwords.words('english'))
def remove_stopwords(text, stop_words=stop_words):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words and word.lower()]
    return " ".join(filtered_words)

# %%
#contractions
def expand_contractions(text):
    if not isinstance(text, str) or not text:
        # Return an empty string or the original text if it's not a valid string
        return text

    try:
        # Use contractions.fix to expand contractions in the text
        return contractions.fix(text)
    except IndexError as e:
        print(f"IndexError encountered: {e}")
        # Optionally return the original text if there's an error
        return text

# %%
# Remove punctuation except for specific cases like "Dr." or "Mr."
def remove_punctuation(text):
    # Replace specific abbreviations with placeholders
    text = re.sub(r'\b(Dr|Mr|Ms|Mrs)\.', r'\1_PLACEHOLDER_', text)
    
    # Remove all punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # Restore the abbreviations
    text = text.replace('_PLACEHOLDER_', '.')
    
    return text

# %%
print("\033[34mPre Processing the data\n\033[0m")
def preprocess_text(text):
    text = expand_contractions(text)       # Step 1: Expand contractions
    text = standardize_dates(text)         # Step 2: Normalize dates
    text = lowercase_text(text)            # Step 3: Convert to lowercase
    text = remove_punctuation(text)        # Step 4: Remove punctuation but keep specific cases
    text = remove_stopwords(text)          # Step 5: Remove stopwords
    text = lemmatize_text(text)            # Step 6: Lemmatize the text
    return text

# Example usage

df.iloc[:, 4] = df.iloc[:, 4].apply(preprocess_text)

print("\033[32mPre Processing Completed!\n\033[0m")
# Out:
# Pre Processing the data
# IndexError encountered: string index out of range
# IndexError encountered: string index out of range
# Pre Processing Completed!

# %%
# histogram of word count after pre-processing
df['word_count'] = df[4].apply(lambda x: len(x.split()))
avg_word_count = df['word_count'].mean()
print(f'Average word count: {avg_word_count:.2f}')
# Plotting the histogram of word counts
plt.figure(figsize=(10, 2))
plt.hist(df['word_count'], bins=80, color='skyblue', edgecolor='black')
plt.title('Histogram of Word Counts in summarization of movies')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Average word count: 204.93

# %%
# Flatten all words from the 4th column into a single list after pre-processing
all_words = [word for row in df[4] for word in row.split()]

word_counter = Counter(all_words)

top_10_words = word_counter.most_common(10)

for word, count in top_10_words:
    print(f"{word}: {count}")

words, counts = zip(*top_10_words)

plt.figure(figsize=(10, 4))
plt.bar(words, counts, color='lightcoral')
plt.title('Top 10 Most Common Words in 4th Column')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate word labels for better readability
plt.tight_layout()
plt.show()
# Out:
# find: 7520
# one: 6738
# get: 6657
# go: 6400
# take: 6198
# back: 5679
# tell: 5446
# father: 5130
# friend: 4791
# kill: 4709

# %% [markdown]
# # Data after Pre Processing

# %%
# Generate a word cloud after pre-processing
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counter)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off the axis
plt.title('Word Cloud of Words in 4th Column')
plt.show()

# %% [markdown]
# ## Carregar o modelo ou Criar um novo
# #### Conforme o nome dado a variavel 'newPKL'

# %%
plots = df.iloc[:, 4]  # Preprocess the plots
genres = df.iloc[:, 2]  # Genres

plots_train, plots_test, genres_train, genres_test = train_test_split(plots, genres, test_size=0.2, random_state=42)

# %%
# Tokenize and train FastText embeddings on the training data only
tokenized_plots_train = [plot.split() for plot in plots_train]
embedding_dim = 300
fasttext_model = FastText(sentences=tokenized_plots_train, vector_size=embedding_dim, window=5, min_count=1, sg=1, epochs=10)

# %%
# Tokenize the plots (fit on training data and transform both train and test)
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(plots_train)
sequences_train = tokenizer.texts_to_sequences(plots_train)
sequences_test = tokenizer.texts_to_sequences(plots_test)
word_index = tokenizer.word_index

# %%
# Pad the sequences
data_train = pad_sequences(sequences_train, maxlen=100)
data_test = pad_sequences(sequences_test, maxlen=100)

# %%
# Create an embedding matrix using FastText trained on training data
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    if word in fasttext_model.wv:
        embedding_matrix[i] = fasttext_model.wv[word]
        
# Encode the genres
label_encoder = LabelEncoder()
labels_train = label_encoder.fit_transform(genres_train)
labels_test = label_encoder.transform(genres_test)

# %%
# Build and compile the LSTM model
model = Sequential()
model.add(Embedding(input_dim=len(word_index) + 1,
                    output_dim=embedding_dim,
                    weights=[embedding_matrix],
                    input_length=100,
                    trainable=False))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(9, activation='softmax'))  # Assuming 9 genres
# Out:
# 2024-10-06 16:03:20.365680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 16:03:20.370530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 16:03:20.373215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model on the training data
model.fit(data_train, labels_train, epochs=12, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/25
# 2024-10-06 16:03:20.766072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 16:03:20.768978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 16:03:20.772324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 16:03:21.442954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 16:03:21.446818: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 16:03:21.449430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 161/161 [==============================] - ETA: 0s - loss: 1.7326 - accuracy: 0.3535
# 2024-10-06 16:04:25.126414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 16:04:25.128417: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 16:04:25.130108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 161/161 [==============================] - 66s 385ms/step - loss: 1.7326 - accuracy: 0.3535 - val_loss: 1.4195 - val_accuracy: 0.4872
# Epoch 2/25
# 161/161 [==============================] - 110s 683ms/step - loss: 1.3963 - accuracy: 0.4921 - val_loss: 1.3116 - val_accuracy: 0.5128
# Epoch 3/25
# 161/161 [==============================] - 95s 590ms/step - loss: 1.2496 - accuracy: 0.5431 - val_loss: 1.1928 - val_accuracy: 0.5781
# Epoch 4/25
# 161/161 [==============================] - 135s 837ms/step - loss: 1.1783 - accuracy: 0.5825 - val_loss: 1.1983 - val_accuracy: 0.5936
# Epoch 5/25
# 161/161 [==============================] - 133s 827ms/step - loss: 1.0787 - accuracy: 0.6218 - val_loss: 1.2326 - val_accuracy: 0.5773
# Epoch 6/25
# 161/161 [==============================] - 117s 725ms/step - loss: 1.0315 - accuracy: 0.6369 - val_loss: 1.1224 - val_accuracy: 0.6030
# Epoch 7/25
# 161/161 [==============================] - 108s 672ms/step - loss: 0.9680 - accuracy: 0.6612 - val_loss: 1.1221 - val_accuracy: 0.6037
# Epoch 8/25
# 161/161 [==============================] - 24s 146ms/step - loss: 0.9142 - accuracy: 0.6709 - val_loss: 1.1153 - val_accuracy: 0.6061
# Epoch 9/25
# 161/161 [==============================] - 99s 615ms/step - loss: 0.8590 - accuracy: 0.6980 - val_loss: 1.0970 - val_accuracy: 0.6371
# Epoch 10/25
# 161/161 [==============================] - 168s 1s/step - loss: 0.8209 - accuracy: 0.7042 - val_loss: 1.1802 - val_accuracy: 0.6123
# Epoch 11/25
# 161/161 [==============================] - 70s 425ms/step - loss: 0.7890 - accuracy: 0.7123 - val_loss: 1.1673 - val_accuracy: 0.5967
# Epoch 12/25
# 161/161 [==============================] - 34s 212ms/step - loss: 0.7376 - accuracy: 0.7341 - val_loss: 1.1450 - val_accuracy: 0.6200
# Epoch 13/25
# 161/161 [==============================] - 78s 484ms/step - loss: 0.6867 - accuracy: 0.7487 - val_loss: 1.1287 - val_accuracy: 0.6270
# Epoch 14/25
# 161/161 [==============================] - 122s 751ms/step - loss: 0.6368 - accuracy: 0.7609 - val_loss: 1.0867 - val_accuracy: 0.6278
# Epoch 15/25
# 161/161 [==============================] - 133s 829ms/step - loss: 0.5876 - accuracy: 0.7864 - val_loss: 1.1985 - val_accuracy: 0.6278
# Epoch 16/25
# 161/161 [==============================] - 133s 824ms/step - loss: 0.5725 - accuracy: 0.7946 - val_loss: 1.2068 - val_accuracy: 0.6356
# Epoch 17/25
# 161/161 [==============================] - 26s 161ms/step - loss: 0.4904 - accuracy: 0.8231 - val_loss: 1.3044 - val_accuracy: 0.6084
# Epoch 18/25
# 161/161 [==============================] - 26s 161ms/step - loss: 0.4426 - accuracy: 0.8445 - val_loss: 1.3699 - val_accuracy: 0.5967
# Epoch 19/25
# 161/161 [==============================] - 77s 481ms/step - loss: 0.4112 - accuracy: 0.8482 - val_loss: 1.3478 - val_accuracy: 0.6084
# Epoch 20/25
# 161/161 [==============================] - 21s 132ms/step - loss: 0.3730 - accuracy: 0.8669 - val_loss: 1.3572 - val_accuracy: 0.6138
# Epoch 21/25
# 161/161 [==============================] - 17s 103ms/step - loss: 0.3342 - accuracy: 0.8762 - val_loss: 1.4726 - val_accuracy: 0.5998
# Epoch 22/25
# 161/161 [==============================] - 93s 575ms/step - loss: 0.2834 - accuracy: 0.9015 - val_loss: 1.4519 - val_accuracy: 0.6193
# Epoch 23/25
# 161/161 [==============================] - 19s 118ms/step - loss: 0.2700 - accuracy: 0.9034 - val_loss: 1.6629 - val_accuracy: 0.6333
# Epoch 24/25
# 161/161 [==============================] - 21s 130ms/step - loss: 0.2410 - accuracy: 0.9123 - val_loss: 1.6242 - val_accuracy: 0.6177
# Epoch 25/25
# 161/161 [==============================] - 122s 762ms/step - loss: 0.1989 - accuracy: 0.9320 - val_loss: 1.8170 - val_accuracy: 0.5991

# %%
# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(data_test, labels_test)
print(f"Test Accuracy: {test_acc}")
# Out:
# 51/51 [==============================] - 3s 61ms/step - loss: 1.8976 - accuracy: 0.5929
# Test Accuracy: 0.592914879322052

# %%
# Make predictions on the test set
y_pred = model.predict(data_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(labels_test, y_pred_classes)

# Optionally, display the confusion matrix as a heatmap
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix for Genre Prediction")
plt.xlabel("Predicted Genre")
plt.ylabel("True Genre")
plt.show()
# Out:
# 2024-10-06 16:37:48.548420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 16:37:48.551076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 16:37:48.553345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 51/51 [==============================] - 6s 104ms/step

# %%
# Calculate accuracy
accuracy = accuracy_score(labels_test, y_pred_classes)

# Calculate precision, recall, and F1 score
precision = precision_score(labels_test, y_pred_classes, average='weighted')  # Use 'macro' for unweighted average
recall = recall_score(labels_test, y_pred_classes, average='weighted')  # Use 'macro' for unweighted average
f1 = f1_score(labels_test, y_pred_classes, average='weighted')  # Use 'macro' for unweighted average

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Optional: Detailed classification report
print("\nClassification Report:\n", classification_report(labels_test, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# Accuracy: 0.5929
# Precision: 0.6229
# Recall: 0.5929
# F1 Score: 0.5980
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       action       0.58      0.41      0.48       202
#    animation       0.85      0.60      0.70       115
#       comedy       0.43      0.70      0.53       223
#        crime       0.53      0.42      0.47       108
#        drama       0.49      0.52      0.51       319
#       horror       0.83      0.70      0.76       223
#      romance       0.53      0.48      0.50       186
#       sci-fi       0.34      0.51      0.41        39
#      western       0.93      0.86      0.90       194
#
#     accuracy                           0.59      1609
#    macro avg       0.61      0.58      0.58      1609
# weighted avg       0.62      0.59      0.60      1609

# %%
# Build and compile the Bidirectional LSTM modelbi
modelbi = Sequential()
modelbi.add(Embedding(input_dim=len(word_index) + 1,
                    output_dim=embedding_dim,
                    weights=[embedding_matrix],
                    input_length=100,
                    trainable=False))
# Add the Bidirectional LSTM layer
modelbi.add(Bidirectional(LSTM(128, return_sequences=False)))
modelbi.add(Dropout(0.5))
modelbi.add(Dense(64, activation='relu'))
modelbi.add(Dense(9, activation='softmax'))  # Assuming 9 genres

# Compile the modelbi
modelbi.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the modelbi on the training data
modelbi.fit(data_train, labels_train, epochs=12, batch_size=32, validation_split=0.2)
# Out:
# 2024-10-06 17:47:23.530413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:47:23.535996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:47:23.540084: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 17:47:23.915514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-10-06 17:47:24.043008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:47:24.046901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:47:24.049630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/15
# 2024-10-06 17:47:24.821297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:47:24.825988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:47:24.828444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 17:47:25.172531: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-10-06 17:47:25.312195: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:47:25.315786: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:47:25.318565: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 17:47:26.641533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-10-06 17:47:27.495691: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:47:27.501068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:47:27.504196: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 17:47:27.798222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-10-06 17:47:27.893710: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:47:27.896870: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:47:27.899530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 17:47:28.815011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 161/161 [==============================] - ETA: 0s - loss: 1.7113 - accuracy: 0.3691
# 2024-10-06 17:50:59.449127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:50:59.452383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:50:59.454634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 17:50:59.662515: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-10-06 17:50:59.742490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 17:50:59.745943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 17:50:59.748430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 161/161 [==============================] - 232s 1s/step - loss: 1.7113 - accuracy: 0.3691 - val_loss: 1.3730 - val_accuracy: 0.5012
# Epoch 2/15
# 161/161 [==============================] - 301s 2s/step - loss: 1.3494 - accuracy: 0.5048 - val_loss: 1.2768 - val_accuracy: 0.5260
# Epoch 3/15
# 161/161 [==============================] - 263s 2s/step - loss: 1.1765 - accuracy: 0.5743 - val_loss: 1.1184 - val_accuracy: 0.6084
# Epoch 4/15
# 161/161 [==============================] - 246s 2s/step - loss: 1.1070 - accuracy: 0.5916 - val_loss: 1.1351 - val_accuracy: 0.6006
# Epoch 5/15
# 161/161 [==============================] - 256s 2s/step - loss: 1.0347 - accuracy: 0.6247 - val_loss: 1.0710 - val_accuracy: 0.6263
# Epoch 6/15
# 161/161 [==============================] - 262s 2s/step - loss: 0.9425 - accuracy: 0.6620 - val_loss: 1.1347 - val_accuracy: 0.6045
# Epoch 7/15
# 161/161 [==============================] - 492s 3s/step - loss: 0.9029 - accuracy: 0.6741 - val_loss: 1.0920 - val_accuracy: 0.6154
# Epoch 8/15
# 161/161 [==============================] - 683s 4s/step - loss: 0.8127 - accuracy: 0.7055 - val_loss: 1.1385 - val_accuracy: 0.6115
# Epoch 9/15
# 161/161 [==============================] - 630s 4s/step - loss: 0.7709 - accuracy: 0.7139 - val_loss: 1.1470 - val_accuracy: 0.5998
# Epoch 10/15
# 161/161 [==============================] - 620s 4s/step - loss: 0.6912 - accuracy: 0.7444 - val_loss: 1.1527 - val_accuracy: 0.5998
# Epoch 11/15
# 161/161 [==============================] - 477s 3s/step - loss: 0.6352 - accuracy: 0.7730 - val_loss: 1.1572 - val_accuracy: 0.6216
# Epoch 12/15
# 161/161 [==============================] - 351s 2s/step - loss: 0.5792 - accuracy: 0.7862 - val_loss: 1.2352 - val_accuracy: 0.6239
# Epoch 13/15
# 161/161 [==============================] - 394s 2s/step - loss: 0.5149 - accuracy: 0.8138 - val_loss: 1.2750 - val_accuracy: 0.6022
# Epoch 14/15
# 161/161 [==============================] - 412s 3s/step - loss: 0.4599 - accuracy: 0.8311 - val_loss: 1.4144 - val_accuracy: 0.5695
# Epoch 15/15
# 161/161 [==============================] - 295s 2s/step - loss: 0.4051 - accuracy: 0.8540 - val_loss: 1.4173 - val_accuracy: 0.6107

# %%
# Evaluate the model on the test data
test_loss, test_acc = modelbi.evaluate(data_test, labels_test)
print(f"Test Accuracy: {test_acc}")
# Out:
# 51/51 [==============================] - 11s 216ms/step - loss: 1.4002 - accuracy: 0.6097
# Test Accuracy: 0.6096954345703125

# %%
# Make predictions on the test set
y_pred = modelbi.predict(data_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(labels_test, y_pred_classes)

# Optionally, display the confusion matrix as a heatmap
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix for Genre Prediction")
plt.xlabel("Predicted Genre")
plt.ylabel("True Genre")
plt.show()
# Out:
# 2024-10-06 19:26:10.850367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 19:26:10.858242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 19:26:10.861424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-10-06 19:26:11.747107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-10-06 19:26:12.059337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-10-06 19:26:12.065020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-10-06 19:26:12.071270: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 51/51 [==============================] - 14s 225ms/step

# %%
# Calculate accuracy
accuracy = accuracy_score(labels_test, y_pred_classes)

# Calculate precision, recall, and F1 score
precision = precision_score(labels_test, y_pred_classes, average='weighted')  # Use 'macro' for unweighted average
recall = recall_score(labels_test, y_pred_classes, average='weighted')  # Use 'macro' for unweighted average
f1 = f1_score(labels_test, y_pred_classes, average='weighted')  # Use 'macro' for unweighted average

# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Optional: Detailed classification report
print("\nClassification Report:\n", classification_report(labels_test, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# Accuracy: 0.6097
# Precision: 0.6079
# Recall: 0.6097
# F1 Score: 0.6069
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       action       0.54      0.55      0.54       202
#    animation       0.69      0.73      0.71       115
#       comedy       0.49      0.49      0.49       223
#        crime       0.56      0.56      0.56       108
#        drama       0.50      0.51      0.51       319
#       horror       0.71      0.84      0.77       223
#      romance       0.58      0.45      0.51       186
#       sci-fi       0.38      0.31      0.34        39
#      western       0.93      0.88      0.90       194
#
#     accuracy                           0.61      1609
#    macro avg       0.60      0.59      0.59      1609
# weighted avg       0.61      0.61      0.61      1609

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from xgboost import XGBClassifier
import matplotlib.pyplot as plt

# Step 1: Generate plot-level embeddings by averaging the word embeddings with tokenized plots
tokenized_plots_train = [plot.split() for plot in plots_train]
tokenized_plots_test = [plot.split() for plot in plots_test]

# Step 1: Generate plot-level embeddings by averaging the word embeddings
def get_average_embedding(sequences, fasttext_model, embedding_dim):
    averaged_embeddings = []
    for sequence in sequences:
        # Only use words that exist in the FastText vocabulary
        word_vectors = [fasttext_model.wv[word] for word in sequence if word in fasttext_model.wv]
        if word_vectors:
            averaged_embeddings.append(np.mean(word_vectors, axis=0))
        else:
            # If there are no words in the sequence that exist in the FastText vocab, use a zero vector
            averaged_embeddings.append(np.zeros(embedding_dim))
    return np.array(averaged_embeddings)

# Convert tokenized sequences into FastText embeddings
train_embeddings = get_average_embedding(tokenized_plots_train, fasttext_model, embedding_dim)
test_embeddings = get_average_embedding(tokenized_plots_test, fasttext_model, embedding_dim)

# Ensure no NaN values in embeddings
train_embeddings = np.nan_to_num(train_embeddings, nan=0.0, posinf=0.0, neginf=0.0)
test_embeddings = np.nan_to_num(test_embeddings, nan=0.0, posinf=0.0, neginf=0.0)

# Step 2: Train an XGBoost classifier on the averaged FastText embeddings
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
xgb_model.fit(train_embeddings, labels_train)

# Step 3: Make predictions on the test set
y_pred = xgb_model.predict(test_embeddings)

# Step 4: Evaluate the model
accuracy = accuracy_score(labels_test, y_pred)
precision = precision_score(labels_test, y_pred, average='weighted')
recall = recall_score(labels_test, y_pred, average='weighted')
f1 = f1_score(labels_test, y_pred, average='weighted')

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Step 5: Generate the confusion matrix
cm = confusion_matrix(labels_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix for Genre Prediction (XGBoost)")
plt.xlabel("Predicted Genre")
plt.ylabel("True Genre")
plt.show()

# Step 6: Optional: Detailed classification report
print("\nClassification Report:\n", classification_report(labels_test, y_pred, target_names=label_encoder.classes_))
# Out:
# Accuracy: 0.6339
# Precision: 0.6560
# Recall: 0.6339
# F1 Score: 0.6376
# Classification Report:
#                precision    recall  f1-score   support
#
#       action       0.56      0.61      0.59       202
#    animation       0.90      0.68      0.77       115
#       comedy       0.49      0.49      0.49       223
#        crime       0.69      0.48      0.57       108
#        drama       0.49      0.67      0.56       319
#       horror       0.81      0.81      0.81       223
#      romance       0.61      0.52      0.56       186
#       sci-fi       0.59      0.33      0.43        39
#      western       0.93      0.79      0.86       194
#
#     accuracy                           0.63      1609
#    macro avg       0.68      0.60      0.63      1609
# weighted avg       0.66      0.63      0.64      1609

# %%
from sklearn import svm

# SVM with FastText embeddings
clf_fasttext = svm.SVC(kernel='linear')

# Train the model
clf_fasttext.fit(train_embeddings, labels_train)

# Predict on the test set
y_pred_fasttext = clf_fasttext.predict(test_embeddings)

# Classification report and confusion matrix
print(classification_report(y_true=labels_test, y_pred=y_pred_fasttext, labels=np.unique(labels_train), zero_division=1))

# Plot confusion matrix
cm_fasttext = confusion_matrix(labels_test, y_pred_fasttext, labels=clf_fasttext.classes_)
disp_fasttext = ConfusionMatrixDisplay(confusion_matrix=cm_fasttext, display_labels=label_encoder.classes_)
disp_fasttext.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.63      0.62       202
#            1       0.89      0.75      0.81       115
#            2       0.53      0.54      0.54       223
#            3       0.67      0.48      0.56       108
#            4       0.50      0.62      0.55       319
#            5       0.83      0.86      0.85       223
#            6       0.59      0.50      0.54       186
#            7       0.65      0.38      0.48        39
#            8       0.91      0.89      0.90       194
#
#     accuracy                           0.66      1609
#    macro avg       0.69      0.63      0.65      1609
# weighted avg       0.67      0.66      0.66      1609
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
